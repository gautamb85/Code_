# %%
# %%writefile dae_iv_extractor.py
import htkmfc
import os
import lasagne
import time
import theano
import theano.tensor as T
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import cPickle
import sys
import subprocess
import scipy.io

from fuel.datasets import IndexableDataset
from fuel.schemes import ShuffledScheme, SequentialScheme
from fuel.streams import DataStream

from collections import OrderedDict
import h5py

from fuel.datasets import H5PYDataset
from fuel.converters.base import fill_hdf5_file
from utils import load_data

cFile = sys.argv[1]

f=open(cFile)
lines = f.readlines()
lines = [l.strip() for l in lines]
values = [v.split()[1] for v in lines]

N_HIDDEN = int(values[0])
F_DIM = int(values[1])
LEARNING_RATE = np.cast['float32'](values[2])
NUM_EPOCHS = int(values[3])
BATCH_SIZE = int(values[4])
MODEL_NAME = values[5]
SAVE_PATH = values[6]
#data
TRAIN_FILE = values[7]
VALID_FILE = values[8]
SCRIPT = values[9] #script name 
MSC = values[10] #machine

def build_dnn(net_input=None):

    print("Building network ...")

    l_in = lasagne.layers.InputLayer(shape=(None, F_DIM), input_var = net_input)
    n_batch,_ = l_in.input_var.shape
    #print lasagne.layers.get_output(l_in, inputs={l_in: X}).eval({X: x_dummy}).shape

    #print lasagne.layers.get_output(l_mask, inputs={l_mask: Mask}).eval({Mask: mask}).shape
    
    l_in_drop = lasagne.layers.DropoutLayer(l_in, p=0.2)

    l_hid1 = lasagne.layers.DenseLayer(l_in, num_units=N_HIDDEN, nonlinearity=lasagne.nonlinearities.rectify,
            W=lasagne.init.GlorotUniform())
    
    l_hid1_drop = lasagne.layers.DropoutLayer(l_hid1, p=0.5)

    # Another 800-unit layer:
    l_hid2 = lasagne.layers.DenseLayer(l_hid1_drop, num_units=N_HIDDEN,
            nonlinearity=lasagne.nonlinearities.rectify)

    l_hid2_drop = lasagne.layers.DropoutLayer(l_hid2, p=0.5)
    
    l_hid3 = lasagne.layers.DenseLayer(l_hid2_drop, num_units=N_HIDDEN,
                            nonlinearity=lasagne.nonlinearities.rectify)
    
    l_hid4 = lasagne.layers.DenseLayer(l_hid3, 800,
                            nonlinearity=lasagne.nonlinearities.rectify)

    l_hid5 = lasagne.layers.DenseLayer(l_hid4, num_units=400,
                            nonlinearity=lasagne.nonlinearities.rectify)

    l_out = lasagne.layers.DenseLayer(
            l_hid5, num_units=F_DIM,
            nonlinearity=lasagne.nonlinearities.linear)
    
    return l_out


def main():
        
    X = T.matrix(name='input_ivecs',dtype='float32')
    
     #load data
    #train_set = H5PYDataset(TRAIN_FILE,  which_sets=('train',))
    valid_set = H5PYDataset(VALID_FILE, which_sets=('valid',))

    network = build_dnn(net_input=X)
    
    dae_ivector = lasagne.layers.get_output(network, deterministic=True)

    feature_extr = theano.function([X], dae_ivector)
    
    h1=train_set.open()
    h2=valid_set.open()

    scheme = SequentialScheme(examples=train_set.num_examples, batch_size=512)
    scheme1 = SequentialScheme(examples=valid_set.num_examples, batch_size=512)

    train_stream = DataStream(dataset=train_set, iteration_scheme=scheme)
    valid_stream = DataStream(dataset=valid_set, iteration_scheme=scheme1)

    for data in train_stream.get_epoch_iterator():
        
        t_data, _,t_name = data
        t_ivec = feature_extr(t_data)
        
        for name,ivec in zip(t_name,t_ivec):
            fname = os.path.join(SAVE_PATH,t_name)
            scipy.io.savemat(fname,mdict={'ivec':ivec})


    for data in valid_stream.get_epoch_iterator():
        v_data, _,v_name = data
        v_ivec = feature_extr(v_data)
        
        for name,ivec in zip(v_name,v_ivec):
            fname = os.path.join(SAVE_PATH,v_name)
            scipy.io.savemat(fname,mdict={'ivec':ivec})

if __name__ == '__main__':
    main()
# Out:
# Overwriting dae_iv_extractor.py

# %%
# %load config/ivec_extract.config
n_hidden 1024
f_dim 400
learn_rate 0.001
n_epochs 500
batch_size 512
model_name ivec_DAE_5layer_corrected
save_path /misc/data15/reco/bhattgau/Rnn/projects/ivec_DAE/dae-ivectors-trn/
t_file /misc/data15/reco/bhattgau/Rnn/data/dnn_ivecs/hdf5/nist10_dae_ivecs_repeat_train-final.hdf5
v_file /misc/data15/reco/bhattgau/Rnn/data/dnn_ivecs/hdf5/nist10_dae_ivecs_repeat_valid-final.hdf5 
script ivec_dae.py
machine reco-15

# %%
from fuel.schemes import ShuffledScheme, SequentialScheme
from fuel.streams import DataStream

from collections import OrderedDict
import h5py

from fuel.datasets import H5PYDataset

VALID_FILE='/misc/data15/reco/bhattgau/Rnn/data/dnn_ivecs/hdf5/nist10_dae_ivecs_repeat_valid-final.hdf5'  
#load data
#train_set = H5PYDataset(TRAIN_FILE,  which_sets=('train',))
valid_set = H5PYDataset(VALID_FILE, which_sets=('valid',))

#network = build_dnn(net_input=X)

#dae_ivector = lasagne.layers.get_output(network, deterministic=True)

#feature_extr = theano.function([X], dae_ivector)

#h1=train_set.open()
h2=valid_set.open()

#scheme = ShuffledScheme(examples=train_set.num_examples, batch_size=BATCH_SIZE)
scheme1 = SequentialScheme(examples=valid_set.num_examples, batch_size=64)

#train_stream = DataStream(dataset=train_set, iteration_scheme=scheme)
valid_stream = DataStream(dataset=valid_set, iteration_scheme=scheme1)

#for data in train_stream.get_epoch_iterator():

#    t_data, _,t_name = data
#    t_ivec = feature_extr(t_data)
#    fname = os.path.join(spth,t_name)
#    scipy.io.savemat(fname,mdict={'t_ivec':t_ivec})


for data in valid_stream.get_epoch_iterator():
    _, _,v_name = data
    for n in v_name:
        print n
#       v_ivec = feature_extr(v_data)
#     fname = os.path.join(spth,t_name)
#     scipy.io.savemat(fname,mdict={'v_ivec':v_ivec})
# Out:
# SWPH3_SW4346_30465-b_f.ivp
# SWPH3_SW4346_30106-b_f.ivp
# SWPH3_SW4346_30610-b_f.ivp
# SWPH3_SW4346_32494-a_f.ivp
# SWPH3_SW4346_31176-b_f.ivp
# SWPH3_SW4782_32682-b_m.ivp
# SWPH3_SW4782_32415-b_m.ivp
# SWPH3_SW4782_31460-b_m.ivp
# SWPH3_SW4782_31585-b_m.ivp
# SWPH3_SW4782_30912-a_m.ivp
# SWPH3_SW4782_32606-b_m.ivp
# SWPH3_SW4782_31680-b_m.ivp
# SWPH3_SW4782_31068-a_m.ivp
# SWPH3_SW4782_31318-b_m.ivp
# SWPH3_SW4782_30556-a_m.ivp
# MIX08_MIX107016_tatmd-a_m.ivp
# MIX08_MIX107016_txppv-a_m.ivp
# MIX08_MIX107016_taowm-a_m.ivp
# MIX08_MIX107016_tetpd-a_m.ivp
# MIX08_MIX107016_tcmgs-b_m.ivp
# MIX08_MIX107016_tbsjq-b_m.ivp
# MIX08_MIX107016_twasp-b_m.ivp
# MIX08_MIX107016_tccyw-a_m.ivp
# MIX08_MIX107016_tbncd-a_m.ivp
# MIX08_MIX107016_fnidj-a_m.ivp
# MIX08_MIX107016_fzejy-a_m.ivp
# MIX08_MIX107016_fwmii-b_m.ivp
# SWCELLP2_SW6692_47661-b_m.ivp
# SWCELLP2_SW6692_45553-a_m.ivp
# SWCELLP2_SW6692_45615-a_m.ivp
# SWCELLP2_SW6692_45954-b_m.ivp
# SWCELLP2_SW6692_46845-b_m.ivp
# SWCELLP2_SW6692_45275-a_m.ivp
# SWCELLP2_SW6692_47686-b_m.ivp
# SWCELLP2_SW6692_47570-b_m.ivp
# SWPH2_SW3275_21834-b_m.ivp
# SWPH2_SW3275_20845-b_m.ivp
# SWPH2_SW3275_24376-b_m.ivp
# SWPH2_SW3275_22654-a_m.ivp
# SWPH2_SW3275_23437-b_m.ivp
# SWPH2_SW3275_20070-b_m.ivp
# SWPH2_SW3275_20991-b_m.ivp
# SWPH2_SW3275_20341-b_m.ivp
# SWPH2_SW3275_24497-a_m.ivp
# SWPH2_SW3275_21694-b_m.ivp
# MIX08_MIX105332_thhvk-b_f.ivp
# MIX08_MIX105332_tqcwr-a_f.ivp
# MIX08_MIX105332_tetgx-a_f.ivp
# MIX08_MIX105332_fpswv-b_f.ivp
# MIX08_MIX105332_trvik-a_f.ivp
# MIX05_MIX8197_nbhn-b_m.ivp
# MIX05_MIX8197_njeu-b_m.ivp
# MIX05_MIX8197_ncap-b_m.ivp
# MIX05_MIX8197_ncdz-b_m.ivp
# MIX05_MIX8197_ngcv-a_m.ivp
# MIX05_MIX8197_njhd-b_m.ivp
# MIX05_MIX8197_nddq-a_m.ivp
# MIX05_MIX8197_nnem-b_m.ivp
# MIX06_MIX102090_oejv-a_m.ivp
# MIX06_MIX102090_oerd-a_m.ivp
# MIX06_MIX102090_ofum-b_m.ivp
# MIX06_MIX102090_ocep-b_m.ivp
# MIX06_MIX102090_kbqx-a_m.ivp
# MIX06_MIX102090_oftb-a_m.ivp
# MIX06_MIX102090_ohmj-a_m.ivp
# MIX06_MIX102090_ohzx-a_m.ivp
# MIX06_MIX102090_ofsl-b_m.ivp
# MIX06_MIX102090_ohoi-b_m.ivp
# MIX06_MIX102090_ocwx-b_m.ivp
# MIX06_MIX102090_keby-b_m.ivp
# MIX06_MIX102090_keam-b_m.ivp
# MIX06_MIX102090_ockz-a_m.ivp
# MIX06_MIX102090_oese-b_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH12_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH06_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH13_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH11_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH09_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH12_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH04_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH13_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH13_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH10_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH05_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH07_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH03_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH03_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH08_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH08_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH06_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH09_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH09_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH06_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH05_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH10_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH11_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH03_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH10_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH12_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH11_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH10_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH11_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH02_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH03_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH05_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH06_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH05_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH09_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH08_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH03_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH04_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH08_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH09_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH08_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH09_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH02_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH04_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH07_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH12_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH04_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH11_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH08_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH04_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH11_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH06_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH12_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH05_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH07_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH13_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH05_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH13_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH02_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH06_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH02_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH07_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH02_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH02_m.ivp
# MIX08_MIX105477_20070206_132632_LDC_12039-CH10_m.ivp
# MIX08_MIX105477_20070213_114542_LDC_12039-CH04_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH10_m.ivp
# MIX08_MIX105477_20070208_125051_LDC_12039-CH03_m.ivp
# MIX08_MIX105477_20070206_144327_LDC_12039-CH07_m.ivp
# MIX08_MIX105477_20070208_143234_LDC_12039-CH13_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH07_m.ivp
# MIX08_MIX105477_20070213_125308_LDC_12039-CH12_m.ivp
# MIX08_MIX105477_fpswm-a_m.ivp
# MIX08_MIX105477_tqjwi-b_m.ivp
# MIX08_MIX105477_tpadm-b_m.ivp
# MIX08_MIX105477_tgacu-b_m.ivp
# MIX08_MIX105477_trvie-a_m.ivp
# MIX08_MIX105477_fnzze-a_m.ivp
# MIX08_MIX105477_tdlpu-a_m.ivp
# MIX08_MIX105477_tgrbd-a_m.ivp
# MIX08_MIX105477_fajib-a_m.ivp
# MIX08_MIX105477_tsrlj-b_m.ivp
# MIX08_MIX105477_tttwc-a_m.ivp
# MIX08_MIX105477_tiqyd-a_m.ivp
# SWPH3_SW4785_30777-a_m.ivp
# SWPH3_SW4785_30201-a_m.ivp
# SWPH3_SW4785_31667-a_m.ivp
# SWPH3_SW4785_31608-a_m.ivp
# SWPH3_SW4785_30271-a_m.ivp
# SWPH3_SW4785_31639-a_m.ivp
# SWPH3_SW4785_30986-a_m.ivp
# SWPH3_SW4785_31291-a_m.ivp
# SWPH3_SW4785_31990-b_m.ivp
# SWPH3_SW4785_30557-a_m.ivp
# SWPH3_SW4785_31151-a_m.ivp
# SWPH3_SW4785_30648-a_m.ivp
# SWPH3_SW4785_31172-b_m.ivp
# SWPH3_SW4785_30845-a_m.ivp
# SWPH3_SW4785_31540-a_m.ivp
# SWPH3_SW4785_30294-b_m.ivp
# SWPH3_SW4785_31359-a_m.ivp
# SWPH3_SW4785_30725-a_m.ivp
# SWPH3_SW4785_30913-a_m.ivp
# SWPH3_SW4785_31423-a_m.ivp
# SWPH3_SW4785_30333-b_m.ivp
# SWPH3_SW4785_30461-a_m.ivp
# SWPH3_SW4234_32396-b_f.ivp
# SWPH3_SW4234_32044-a_f.ivp
# SWPH3_SW4234_32040-b_f.ivp
# SWPH3_SW4234_32502-b_f.ivp
# SWPH3_SW4234_31523-b_f.ivp
# SWPH3_SW4234_30677-b_f.ivp
# SWPH3_SW4234_30426-b_f.ivp
# SWPH2_SW3204_23727-b_f.ivp
# SWPH2_SW3204_22080-b_f.ivp
# SWPH2_SW3204_24564-b_f.ivp
# SWPH2_SW3204_23140-a_f.ivp
# SWPH2_SW3204_20034-a_f.ivp
# SWPH2_SW3204_22412-b_f.ivp
# SWPH2_SW3204_20455-b_f.ivp
# SWPH2_SW3204_21251-b_f.ivp
# SWPH2_SW3204_24233-b_f.ivp
# MIX08_MIX103493_tioie-a_m.ivp
# MIX08_MIX103493_fefdd-b_m.ivp
# MIX08_MIX103493_foydj-b_m.ivp
# MIX08_MIX103493_tigta-b_m.ivp
# MIX08_MIX103493_ffbis-b_m.ivp
# MIX08_MIX103493_tfuxj-b_m.ivp
# MIX08_MIX103493_tycis-b_m.ivp
# MIX08_MIX103493_tjlzp-a_m.ivp
# MIX08_MIX105869_tvqha-a_m.ivp
# MIX08_MIX105869_tvrwh-a_m.ivp
# MIX08_MIX105869_trxij-a_m.ivp
# MIX08_MIX105869_tgfeo-a_m.ivp
# MIX08_MIX105869_fljug-b_m.ivp
# MIX08_MIX105869_txtnv-a_m.ivp
# MIX08_MIX105869_tdarn-b_m.ivp
# MIX08_MIX107807_ttmuy-a_m.ivp
# MIX08_MIX107807_tmasq-b_m.ivp
# MIX08_MIX107807_tusjv-a_m.ivp
# MIX08_MIX107807_fuegl-a_m.ivp
# MIX08_MIX107807_tccyw-b_m.ivp
# MIX08_MIX107807_fmegl-a_m.ivp
# MIX08_MIX107807_trnna-b_m.ivp
# MIX08_MIX107807_frssd-a_m.ivp
# MIX08_MIX107807_fxxqc-a_m.ivp
# MIX08_MIX107807_tjdly-b_m.ivp
# MIX08_MIX107807_tacsf-b_m.ivp
# SWCELLP2_SW6744_47375-b_f.ivp
# SWCELLP2_SW6744_45797-b_f.ivp
# SWCELLP2_SW6744_47303-b_f.ivp
# SWCELLP2_SW6744_46142-b_f.ivp
# SWCELLP2_SW6744_45664-b_f.ivp
# SWCELLP2_SW6744_45959-b_f.ivp
# SWCELLP2_SW6744_47358-b_f.ivp
# SWCELLP2_SW6744_46356-b_f.ivp
# MIX06_MIX102367_kdqa-b_f.ivp
# MIX06_MIX102367_kdhd-b_f.ivp
# MIX06_MIX102367_oday-b_f.ivp
# MIX06_MIX102367_oflb-a_f.ivp
# MIX06_MIX102367_kebi-b_f.ivp
# MIX06_MIX102367_kacn-a_f.ivp
# MIX06_MIX102367_odcm-b_f.ivp
# MIX06_MIX102367_kdms-b_f.ivp
# MIX06_MIX102367_oasj-b_f.ivp
# MIX06_MIX102367_kcov-a_f.ivp
# MIX06_MIX102367_kcwi-a_f.ivp
# MIX06_MIX102367_ogeb-a_f.ivp
# MIX06_MIX102367_kdxc-b_f.ivp
# MIX06_MIX102367_kdai-a_f.ivp
# MIX06_MIX101256_oddk-a_m.ivp
# MIX06_MIX101256_kcde-a_m.ivp
# MIX06_MIX101256_kcju-b_m.ivp
# MIX06_MIX101256_ohzk-b_m.ivp
# MIX06_MIX101256_kcqu-a_m.ivp
# MIX06_MIX101256_kekx-b_m.ivp
# MIX06_MIX101256_ochn-a_m.ivp
# MIX06_MIX101256_kczu-a_m.ivp
# MIX06_MIX101256_ocwp-a_m.ivp
# MIX06_MIX101256_kakb-a_m.ivp
# MIX06_MIX101256_odbp-b_m.ivp
# MIX06_MIX101256_objz-b_m.ivp
# MIX06_MIX101256_kchp-a_m.ivp
# MIX06_MIX101256_kbju-b_m.ivp
# SWPH2_SW3769_21421-b_f.ivp
# SWPH2_SW3769_21691-b_f.ivp
# SWPH2_SW3769_22825-a_f.ivp
# SWPH2_SW3769_23697-b_f.ivp
# SWPH2_SW3769_21210-b_f.ivp
# SWPH2_SW3769_22698-a_f.ivp
# SWPH2_SW3769_22501-b_f.ivp
# SWPH2_SW3769_22101-b_f.ivp
# SWPH2_SW3769_21963-b_f.ivp
# SWPH2_SW3769_23032-b_f.ivp
# SWCELLP1_SW5221_43020-a_m.ivp
# SWCELLP1_SW5221_40736-a_m.ivp
# SWCELLP1_SW5221_41014-b_m.ivp
# SWCELLP1_SW5221_40668-a_m.ivp
# SWCELLP1_SW5221_40516-a_m.ivp
# SWCELLP1_SW5221_43267-a_m.ivp
# SWCELLP2_SW5221_46664-a_m.ivp
# SWCELLP2_SW5221_47620-a_m.ivp
# SWCELLP2_SW5221_45017-a_m.ivp
# SWCELLP2_SW5221_46949-a_m.ivp
# SWCELLP1_SW5221_41795-b_m.ivp
# SWCELLP1_SW5221_40554-a_m.ivp
# SWCELLP2_SW5221_46230-a_m.ivp
# SWCELLP2_SW5221_45124-a_m.ivp
# SWCELLP1_SW5221_41853-b_m.ivp
# SWCELLP2_SW5221_45064-a_m.ivp
# SWCELLP1_SW5221_40494-a_m.ivp
# SWCELLP2_SW5221_46538-a_m.ivp
# SWCELLP1_SW5221_42996-a_m.ivp
# SWCELLP1_SW5221_41476-b_m.ivp
# SWCELLP2_SW5221_45308-a_m.ivp
# SWCELLP1_SW5221_40708-a_m.ivp
# SWCELLP1_SW5221_40580-a_m.ivp
# SWCELLP2_SW5221_47166-a_m.ivp
# SWCELLP1_SW5221_40872-b_m.ivp
# SWCELLP1_SW5221_40441-a_m.ivp
# SWCELLP1_SW5221_41270-b_m.ivp
# SWCELLP2_SW5221_46837-a_m.ivp
# SWCELLP1_SW5221_43113-a_m.ivp
# MIX08_MIX104707_tfqwb-b_f.ivp
# MIX08_MIX104707_fmjqa-b_f.ivp
# MIX08_MIX104707_tshde-a_f.ivp
# MIX08_MIX104707_tojru-a_f.ivp
# MIX08_MIX104707_fjboj-a_f.ivp
# MIX08_MIX104707_fzdbx-b_f.ivp
# MIX08_MIX104707_tqgyk-a_f.ivp
# MIX08_MIX104707_tnpoj-a_f.ivp
# MIX08_MIX104707_tnqwv-a_f.ivp
# MIX08_MIX104707_trkjz-b_f.ivp
# MIX08_MIX104707_tjvdx-a_f.ivp
# MIX08_MIX104707_thkcb-a_f.ivp
# SWPH2_SW3043_21599-b_m.ivp
# SWPH2_SW3043_20123-b_m.ivp
# SWPH2_SW3043_20309-b_m.ivp
# SWPH2_SW3043_20634-b_m.ivp
# SWPH2_SW3043_21129-b_m.ivp
# SWPH2_SW3043_20803-b_m.ivp
# SWPH2_SW3043_23971-a_m.ivp
# MIX08_MIX108144_20070530_142436_LDC_15944-CH01_m.ivp
# MIX08_MIX108144_20070402_173930_LDC_94453-CH01_m.ivp
# MIX08_MIX108144_20070316_150103_LDC_20369-CH01_m.ivp
# MIX08_MIX108144_20070830_101937_LDC_11607-CH01_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH11_m.ivp
# MIX08_MIX108144_20070309_173856_LDC_94453-CH01_m.ivp
# MIX08_MIX108144_20070326_173217_LDC_94453-CH01_m.ivp
# MIX08_MIX108144_20070330_165848_LDC_28244-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH10_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH05_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH11_m.ivp
# MIX08_MIX108144_20070306_131949_LDC_51236-CH01_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH03_m.ivp
# MIX08_MIX108144_20070323_160653_LDC_28244-CH01_m.ivp
# MIX08_MIX108144_20070321_102434_LDC_39290-CH01_m.ivp
# MIX08_MIX108144_20070831_092051_LDC_41961-CH01_m.ivp
# MIX08_MIX108144_20070409_140532_LDC_40702-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH11_m.ivp
# MIX08_MIX108144_20070705_120149_LDC_53968-CH01_m.ivp
# MIX08_MIX108144_20070312_154511_LDC_25363-CH01_m.ivp
# MIX08_MIX108144_20070306_165812_LDC_82637-CH01_m.ivp
# MIX08_MIX108144_20070323_165914_LDC_28244-CH01_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH03_m.ivp
# MIX08_MIX108144_20070402_152950_LDC_29123-CH01_m.ivp
# MIX08_MIX108144_20070703_140847_LDC_87622-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH02_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH02_m.ivp
# MIX08_MIX108144_20070323_150640_LDC_20369-CH01_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH12_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH04_m.ivp
# MIX08_MIX108144_20070223_142629_LDC_20369-CH01_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH03_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH08_m.ivp
# MIX08_MIX108144_20070503_115802_LDC_70929-CH01_m.ivp
# MIX08_MIX108144_20070705_110255_LDC_53968-CH01_m.ivp
# MIX08_MIX108144_20070515_164138_LDC_98601-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH06_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH03_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH08_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH10_m.ivp
# MIX08_MIX108144_20070312_134729_LDC_23499-CH01_m.ivp
# MIX08_MIX108144_20070323_173903_LDC_94453-CH01_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH02_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH10_m.ivp
# MIX08_MIX108144_20070404_131912_LDC_79288-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH10_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH07_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH04_m.ivp
# MIX08_MIX108144_20070330_172908_LDC_79288-CH01_m.ivp
# MIX08_MIX108144_20070828_091218_LDC_11607-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH03_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH13_m.ivp
# MIX08_MIX108144_20070319_162642_LDC_74868-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH04_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH02_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH08_m.ivp
# MIX08_MIX108144_20070905_145340_LDC_74868-CH01_m.ivp
# MIX08_MIX108144_20070601_131921_LDC_42122-CH01_m.ivp
# MIX08_MIX108144_20070502_173015_LDC_98601-CH01_m.ivp
# MIX08_MIX108144_20070409_150943_LDC_40702-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH06_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH02_m.ivp
# MIX08_MIX108144_20071210_171116_LDC_55314-CH01_m.ivp
# MIX08_MIX108144_20070321_140603_LDC_23499-CH01_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH04_m.ivp
# MIX08_MIX108144_20070525_152231_LDC_27827-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH09_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH05_m.ivp
# MIX08_MIX108144_20070402_101913_LDC_39290-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH12_m.ivp
# MIX08_MIX108144_20070307_152608_LDC_23499-CH01_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH06_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH07_m.ivp
# MIX08_MIX108144_20070511_142333_LDC_65448-CH01_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH02_m.ivp
# MIX08_MIX108144_20070508_133207_LDC_65448-CH01_m.ivp
# MIX08_MIX108144_20070824_111526_LDC_11607-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH08_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH08_m.ivp
# MIX08_MIX108144_20070525_142351_LDC_27827-CH01_m.ivp
# MIX08_MIX108144_20070824_160032_LDC_10667-CH01_m.ivp
# MIX08_MIX108144_20070330_162721_LDC_79288-CH01_m.ivp
# MIX08_MIX108144_20070907_143022_LDC_74868-CH01_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH07_m.ivp
# MIX08_MIX108144_20070330_180043_LDC_94453-CH01_m.ivp
# MIX08_MIX108144_20070830_091313_LDC_11607-CH01_m.ivp
# MIX08_MIX108144_20070824_100420_LDC_11607-CH01_m.ivp
# MIX08_MIX108144_20070228_150533_LDC_24326-CH01_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH08_m.ivp
# MIX08_MIX108144_20070307_141804_LDC_23499-CH01_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH12_m.ivp
# MIX08_MIX108144_20070703_130515_LDC_87622-CH01_m.ivp
# MIX08_MIX108144_20070731_113738_LDC_45012-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH13_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH09_m.ivp
# MIX08_MIX108144_20070327_151100_LDC_74868-CH01_m.ivp
# MIX08_MIX108144_20070518_160104_LDC_65448-CH01_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH13_m.ivp
# MIX08_MIX108144_20070328_180513_LDC_94453-CH01_m.ivp
# MIX08_MIX108144_20070326_105304_LDC_39290-CH01_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH11_m.ivp
# MIX08_MIX108144_20070824_170335_LDC_10667-CH01_m.ivp
# MIX08_MIX108144_20070320_163227_LDC_28244-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH13_m.ivp
# MIX08_MIX108144_20070320_173034_LDC_28244-CH01_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH06_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH05_m.ivp
# MIX08_MIX108144_20070503_124436_LDC_70929-CH01_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH07_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH13_m.ivp
# MIX08_MIX108144_20070226_172602_LDC_24326-CH01_m.ivp
# MIX08_MIX108144_20070828_102836_LDC_11607-CH01_m.ivp
# MIX08_MIX108144_20070601_140955_LDC_42122-CH01_m.ivp
# MIX08_MIX108144_20070223_132559_LDC_20369-CH01_m.ivp
# MIX08_MIX108144_20070508_143339_LDC_65448-CH01_m.ivp
# MIX08_MIX108144_20070321_145635_LDC_23499-CH01_m.ivp
# MIX08_MIX108144_20070406_141546_LDC_66161-CH01_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH09_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH03_m.ivp
# MIX08_MIX108144_20070518_143456_LDC_65448-CH01_m.ivp
# MIX08_MIX108144_20070307_160700_LDC_74868-CH01_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH12_m.ivp
# MIX08_MIX108144_20070404_142839_LDC_79288-CH01_m.ivp
# MIX08_MIX108144_20070314_153518_LDC_82637-CH01_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH10_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH06_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH10_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH04_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH09_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH05_m.ivp
# MIX08_MIX108144_20070523_165213_LDC_60001-CH05_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH12_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH09_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH07_m.ivp
# MIX08_MIX108144_20070323_141321_LDC_20369-CH01_m.ivp
# MIX08_MIX108144_20070515_160654_LDC_60001-CH06_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH11_m.ivp
# MIX08_MIX108144_20070312_131111_LDC_51236-CH01_m.ivp
# MIX08_MIX108144_20070409_172353_LDC_37651-CH01_m.ivp
# MIX08_MIX108144_20070511_153113_LDC_65448-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH05_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH12_m.ivp
# MIX08_MIX108144_20070205_150426_LDC_60001-CH04_m.ivp
# MIX08_MIX108144_20070404_100031_LDC_39290-CH01_m.ivp
# MIX08_MIX108144_20070312_145154_LDC_23499-CH01_m.ivp
# MIX08_MIX108144_20070515_174359_LDC_98601-CH01_m.ivp
# MIX08_MIX108144_20070907_131513_LDC_74868-CH01_m.ivp
# MIX08_MIX108144_20070523_150249_LDC_60001-CH11_m.ivp
# MIX08_MIX108144_20070131_120835_LDC_60001-CH13_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH07_m.ivp
# MIX08_MIX108144_20070328_143721_LDC_82637-CH01_m.ivp
# MIX08_MIX108144_20070502_164113_LDC_98601-CH01_m.ivp
# MIX08_MIX108144_20070330_155326_LDC_28244-CH01_m.ivp
# MIX08_MIX108144_20070515_135550_LDC_60001-CH09_m.ivp
# MIX08_MIX108144_tcfek-a_m.ivp
# MIX08_MIX108144_tbqqp-b_m.ivp
# MIX08_MIX108144_fgznw-a_m.ivp
# MIX08_MIX108144_tfacq-a_m.ivp
# MIX08_MIX108144_tuwbr-b_m.ivp
# MIX08_MIX108144_tyjnu-b_m.ivp
# MIX08_MIX108144_fgznu-a_m.ivp
# MIX08_MIX108144_tmswt-b_m.ivp
# MIX08_MIX108144_twotq-b_m.ivp
# MIX08_MIX108144_ftrcu-a_m.ivp
# MIX08_MIX108144_tuwbp-b_m.ivp
# MIX08_MIX108144_tamwc-a_m.ivp
# MIX08_MIX108144_fhcks-a_m.ivp
# MIX08_MIX108144_tqnwe-a_m.ivp
# MIX08_MIX108144_twxgq-b_m.ivp
# MIX08_MIX108144_fgzny-a_m.ivp
# MIX08_MIX108144_tofdw-b_m.ivp
# MIX08_MIX108144_fivsw-a_m.ivp
# MIX08_MIX108144_tnoiu-a_m.ivp
# MIX04_MIX5826_tdsc-x_m.ivp
# MIX04_MIX5826_xbkx-x_m.ivp
# MIX04_MIX5826_xcdu-x_m.ivp
# MIX04_MIX5826_tdsj-x_m.ivp
# MIX04_MIX5826_tikq-x_m.ivp
# MIX04_MIX5826_xflb-x_m.ivp
# MIX04_MIX5826_xcfq-x_m.ivp
# MIX04_MIX5826_xffi-x_m.ivp
# MIX04_MIX5826_tbtc-x_m.ivp
# MIX04_MIX5826_tcbx-x_m.ivp
# MIX04_MIX5826_tahq-x_m.ivp
# MIX04_MIX5826_xbnp-x_m.ivp
# MIX04_MIX5826_xbig-x_m.ivp
# MIX04_MIX5826_teex-x_m.ivp
# MIX04_MIX5826_xbjg-x_m.ivp
# MIX04_MIX5826_talh-x_m.ivp
# MIX06_MIX2503_pagh-b_f.ivp
# MIX06_MIX2503_pdpl-b_f.ivp
# MIX06_MIX2503_pbjf-a_f.ivp
# MIX06_MIX2503_pakg-b_f.ivp
# MIX06_MIX2503_pedt-b_f.ivp
# MIX06_MIX2503_pdhb-a_f.ivp
# MIX06_MIX2503_pcsq-a_f.ivp
# MIX06_MIX2503_pewz-b_f.ivp
# MIX06_MIX2503_pdbd-b_f.ivp
# MIX06_MIX2503_pctl-b_f.ivp
# MIX06_MIX2503_pdqc-b_f.ivp
# MIX06_MIX2503_pgbp-b_f.ivp
# MIX06_MIX2503_pbgb-b_f.ivp
# MIX06_MIX2503_pcjf-b_f.ivp
# MIX06_MIX2503_pbtq-b_f.ivp
# MIX06_MIX2503_pcvr-b_f.ivp
# MIX06_MIX2503_pfbr-b_f.ivp
# MIX06_MIX2503_pexy-b_f.ivp
# MIX06_MIX2503_pcfo-b_f.ivp
# MIX06_MIX2503_pchg-b_f.ivp
# MIX06_MIX2503_pcwp-b_f.ivp
# MIX06_MIX2503_pein-b_f.ivp
# MIX06_MIX2503_pbzf-b_f.ivp
# MIX06_MIX2503_parm-b_f.ivp
# MIX06_MIX2503_pcfg-b_f.ivp
# MIX06_MIX2503_paul-b_f.ivp
# MIX06_MIX2503_pdwh-b_f.ivp
# MIX06_MIX2503_peur-b_f.ivp
# MIX06_MIX2503_pdhi-a_f.ivp
# MIX06_MIX2503_pevf-b_f.ivp
# MIX06_MIX2503_pcbw-b_f.ivp
# MIX06_MIX2503_pcbn-b_f.ivp
# MIX06_MIX2503_pfwp-b_f.ivp
# MIX06_MIX2503_pcfv-b_f.ivp
# MIX06_MIX2503_pfyy-b_f.ivp
# MIX06_MIX2503_pchq-a_f.ivp
# MIX06_MIX2503_pdaf-b_f.ivp
# MIX06_MIX2503_pcui-b_f.ivp
# MIX06_MIX2503_peog-b_f.ivp
# MIX06_MIX2503_pfnj-b_f.ivp
# MIX06_MIX2503_pdoj-b_f.ivp
# MIX06_MIX2503_peve-a_f.ivp
# MIX06_MIX2503_pbjd-b_f.ivp
# MIX06_MIX2503_pfzf-b_f.ivp
# MIX06_MIX2503_pgfj-a_f.ivp
# MIX06_MIX2503_pahw-b_f.ivp
# MIX06_MIX2503_pdvr-b_f.ivp
# MIX06_MIX2503_perq-a_f.ivp
# MIX06_MIX2503_pawx-a_f.ivp
# MIX06_MIX2503_pcby-b_f.ivp
# MIX06_MIX2503_parv-b_f.ivp
# MIX06_MIX2503_pdjv-b_f.ivp
# MIX06_MIX2503_perp-b_f.ivp
# MIX06_MIX2503_pbxo-b_f.ivp
# MIX06_MIX2503_ojbn-b_f.ivp
# MIX06_MIX2503_ojcm-b_f.ivp
# MIX06_MIX2503_oixg-b_f.ivp
# MIX06_MIX2503_ojdw-b_f.ivp
# MIX06_MIX2503_ojlz-b_f.ivp
# MIX06_MIX2503_ojcp-b_f.ivp
# MIX06_MIX2503_kerl-b_f.ivp
# MIX06_MIX101746_oikg-a_f.ivp
# MIX06_MIX101746_octl-b_f.ivp
# MIX06_MIX101746_kdcf-a_f.ivp
# MIX06_MIX101746_ocnr-a_f.ivp
# MIX06_MIX101746_ocle-b_f.ivp
# MIX06_MIX101746_ofhg-a_f.ivp
# MIX06_MIX101746_kban-a_f.ivp
# MIX06_MIX101746_kdxl-a_f.ivp
# MIX06_MIX101746_ohbz-a_f.ivp
# MIX06_MIX101746_kblm-a_f.ivp
# MIX06_MIX101746_kdxd-a_f.ivp
# MIX06_MIX101746_oilm-a_f.ivp
# MIX06_MIX101746_oexo-b_f.ivp
# MIX06_MIX101746_kcgi-a_f.ivp
# MIX06_MIX101746_kebf-b_f.ivp
# MIX06_MIX101746_ofgo-a_f.ivp
# MIX06_MIX101746_obyg-a_f.ivp
# MIX06_MIX101746_ofbu-a_f.ivp
# MIX06_MIX101746_kdyn-a_f.ivp
# SWCELLP2_SW6335_47613-a_f.ivp
# SWCELLP2_SW6335_45481-b_f.ivp
# SWCELLP2_SW6335_46533-b_f.ivp
# SWCELLP2_SW6335_46267-b_f.ivp
# SWCELLP2_SW6335_45184-b_f.ivp
# SWCELLP2_SW6335_45345-b_f.ivp
# SWCELLP2_SW6335_45101-b_f.ivp
# SWCELLP2_SW6335_47259-a_f.ivp
# SWCELLP2_SW6335_46861-b_f.ivp
# SWCELLP2_SW6335_46629-b_f.ivp
# SWCELLP2_SW6335_47359-a_f.ivp
# SWCELLP2_SW6335_45855-a_f.ivp
# SWCELLP2_SW6335_45426-b_f.ivp
# MIX05_MIX2043_nowa-b_f.ivp
# MIX05_MIX2043_nkjk-a_f.ivp
# MIX05_MIX2043_nmpc-b_f.ivp
# MIX05_MIX2043_nnfg-a_f.ivp
# MIX05_MIX2043_ndzo-b_f.ivp
# MIX05_MIX2043_nkjh-a_f.ivp
# MIX05_MIX2043_novp-a_f.ivp
# MIX06_MIX2043_oitn-b_f.ivp
# MIX08_MIX102548_totcf-a_m.ivp
# MIX08_MIX102548_tokcp-a_m.ivp
# MIX06_MIX102548_odbe-b_m.ivp
# MIX08_MIX102548_thntg-a_m.ivp
# MIX08_MIX102548_tycfa-b_m.ivp
# MIX08_MIX102548_fuqvs-b_m.ivp
# MIX08_MIX102548_tmbnc-b_m.ivp
# MIX08_MIX102548_trthr-a_m.ivp
# MIX08_MIX102548_tjtde-a_m.ivp
# MIX08_MIX102548_tsiew-b_m.ivp
# MIX06_MIX102548_kbtd-b_m.ivp
# MIX08_MIX102548_tvkji-b_m.ivp
# MIX08_MIX102548_tmzfu-a_m.ivp
# SWPH2_SW3576_24277-a_f.ivp
# SWPH2_SW3576_20790-a_f.ivp
# SWPH2_SW3576_21220-a_f.ivp
# SWPH2_SW3576_20278-b_f.ivp
# SWPH2_SW3576_24063-b_f.ivp
# SWPH2_SW3576_23695-b_f.ivp
# SWPH2_SW3576_20192-a_f.ivp
# SWPH2_SW3576_23106-b_f.ivp
# SWPH2_SW3576_20542-a_f.ivp
# SWPH2_SW3576_22732-b_f.ivp
# SWPH2_SW3576_24061-a_f.ivp
# SWCELLP2_SW6312_46563-a_f.ivp
# SWCELLP2_SW6312_46475-b_f.ivp
# SWCELLP2_SW6312_45175-a_f.ivp
# SWCELLP2_SW6312_45839-a_f.ivp
# SWCELLP2_SW6312_45728-a_f.ivp
# SWCELLP2_SW6312_46377-b_f.ivp
# SWCELLP2_SW6312_46939-b_f.ivp
# SWCELLP2_SW6312_46068-a_f.ivp
# MIX05_MIX7656_ndlk-a_f.ivp
# MIX06_MIX7656_jbxs-b_f.ivp
# MIX06_MIX7656_jgfv-b_f.ivp
# MIX06_MIX7656_jfoe-b_f.ivp
# MIX06_MIX7656_jfsk-a_f.ivp
# MIX06_MIX7656_jdqv-a_f.ivp
# MIX06_MIX7656_jhbz-a_f.ivp
# MIX06_MIX7656_jgsw-a_f.ivp
# MIX06_MIX7656_jhiv-a_f.ivp
# MIX08_MIX111370_20071009_164700_LDCSID400579CID24099_59182-CH02_m.ivp
# MIX08_MIX111370_20071009_164700_LDCSID400579CID24099_59182-CH05_m.ivp
# MIX08_MIX111370_20071015_140947_LDCSID403484CID24291_59182-CH07_m.ivp
# MIX08_MIX111370_20071009_164700_LDCSID400579CID24099_59182-CH09_m.ivp
# MIX08_MIX111370_20071015_140947_LDCSID403484CID24291_59182-CH06_m.ivp
# MIX08_MIX111370_20071015_140947_LDCSID403484CID24291_59182-CH04_m.ivp
# MIX08_MIX111370_20071015_140947_LDCSID403484CID24291_59182-CH09_m.ivp
# MIX08_MIX111370_20071015_140947_LDCSID403484CID24291_59182-CH05_m.ivp
# MIX08_MIX111370_20071009_164700_LDCSID400579CID24099_59182-CH04_m.ivp
# MIX08_MIX111370_20071015_140947_LDCSID403484CID24291_59182-CH02_m.ivp
# MIX08_MIX111370_20071009_164700_LDCSID400579CID24099_59182-CH06_m.ivp
# MIX08_MIX111370_20071009_164700_LDCSID400579CID24099_59182-CH07_m.ivp
# MIX08_MIX111370_tzpzk-b_m.ivp
# MIX08_MIX111370_tdfmy-b_m.ivp
# MIX08_MIX111370_tgsuz-a_m.ivp
# MIX08_MIX111370_tzvwa-b_m.ivp
# MIX08_MIX111370_tbbat-a_m.ivp
# MIX08_MIX111370_tsbnr-a_m.ivp
# MIX08_MIX111370_ttfrv-b_m.ivp
# MIX08_MIX111370_fnvqi-b_m.ivp
# MIX08_MIX111370_teojr-b_m.ivp
# MIX08_MIX111370_thgxp-a_m.ivp
# MIX08_MIX111370_fktad-a_m.ivp
# MIX08_MIX111370_tsvjq-b_m.ivp
# MIX08_MIX111370_tjbcf-b_m.ivp
# MIX08_MIX111370_tiglb-b_m.ivp
# MIX08_MIX111370_fiqus-a_m.ivp
# MIX08_MIX111370_tqafn-b_m.ivp
# MIX08_MIX111370_twiey-a_m.ivp
# MIX08_MIX111370_twrqr-b_m.ivp
# MIX08_MIX111370_tbizb-a_m.ivp
# MIX08_MIX107208_tgise-a_m.ivp
# MIX08_MIX107208_fxvyx-b_m.ivp
# MIX08_MIX107208_tvpzp-a_m.ivp
# MIX08_MIX107208_tjiuf-a_m.ivp
# MIX08_MIX107208_tqkip-a_m.ivp
# MIX08_MIX107208_fuogx-b_m.ivp
# MIX08_MIX107208_tyidj-b_m.ivp
# MIX08_MIX107208_teevw-b_m.ivp
# MIX08_MIX107208_tolhm-b_m.ivp
# MIX08_MIX107208_tlufo-b_m.ivp
# MIX08_MIX107208_ttegh-b_m.ivp
# MIX08_MIX107208_tsqiv-b_m.ivp
# MIX08_MIX107208_tqoga-b_m.ivp
# MIX06_MIX101138_ognf-b_f.ivp
# MIX06_MIX101138_kdjw-a_f.ivp
# MIX06_MIX101138_ogws-b_f.ivp
# MIX06_MIX101138_kcox-b_f.ivp
# MIX06_MIX101138_kavs-b_f.ivp
# MIX06_MIX101138_ofut-b_f.ivp
# MIX06_MIX101138_oaau-a_f.ivp
# MIX06_MIX101138_oezu-b_f.ivp
# MIX06_MIX101138_kcny-b_f.ivp
# MIX06_MIX101138_kazu-b_f.ivp
# MIX06_MIX101138_kdyk-b_f.ivp
# MIX06_MIX101138_kdjt-a_f.ivp
# MIX08_MIX101138_tcdgq-b_f.ivp
# MIX08_MIX101138_fdzvo-b_f.ivp
# MIX06_MIX101138_oaby-a_f.ivp
# MIX06_MIX101138_kcjz-b_f.ivp
# MIX06_MIX101138_odko-a_f.ivp
# MIX08_MIX111140_tixwo-a_f.ivp
# MIX08_MIX111140_tavtw-b_f.ivp
# MIX08_MIX111140_tximy-b_f.ivp
# MIX08_MIX111140_thimj-a_f.ivp
# MIX08_MIX111140_turda-a_f.ivp
# MIX08_MIX111140_toawh-b_f.ivp
# MIX08_MIX111140_fqxzl-b_f.ivp
# MIX08_MIX111140_tttpa-a_f.ivp
# MIX08_MIX111140_tpeau-b_f.ivp
# MIX08_MIX111140_tuqps-a_f.ivp
# SWPH2_SW3233_20437-b_f.ivp
# SWPH2_SW3233_23292-b_f.ivp
# SWPH2_SW3233_21849-b_f.ivp
# SWPH2_SW3233_21528-b_f.ivp
# SWPH2_SW3233_20915-b_f.ivp
# SWPH2_SW3233_22573-a_f.ivp
# SWPH2_SW3233_21384-b_f.ivp
# SWPH2_SW3233_22824-b_f.ivp
# SWPH2_SW3233_23203-b_f.ivp
# SWPH2_SW3960_24515-b_m.ivp
# SWPH2_SW3960_23809-b_m.ivp
# SWPH2_SW3960_23830-a_m.ivp
# SWPH2_SW3960_23768-a_m.ivp
# SWPH2_SW3960_23644-b_m.ivp
# SWPH2_SW3960_23161-b_m.ivp
# SWPH2_SW3960_24243-a_m.ivp
# SWPH2_SW3960_24075-b_m.ivp
# SWPH2_SW3960_24448-b_m.ivp
# SWPH2_SW3960_23842-b_m.ivp
# SWPH2_SW3960_23113-a_m.ivp
# SWPH2_SW3960_23917-a_m.ivp
# SWPH2_SW3170_24201-b_f.ivp
# SWPH2_SW3170_20580-b_f.ivp
# SWPH2_SW3170_20897-b_f.ivp
# SWPH2_SW3170_21714-a_f.ivp
# SWPH2_SW3170_21168-a_f.ivp
# SWPH2_SW3170_20992-b_f.ivp
# SWPH2_SW3170_21677-b_f.ivp
# SWPH2_SW3170_24314-b_f.ivp
# SWPH2_SW3170_20786-b_f.ivp
# SWPH2_SW3170_22182-a_f.ivp
# SWPH2_SW3170_21433-b_f.ivp
# MIX06_MIX8821_keym-a_f.ivp
# MIX06_MIX8821_keri-b_f.ivp
# MIX06_MIX8821_keyh-a_f.ivp
# MIX06_MIX8821_keun-a_f.ivp
# MIX06_MIX8821_kfaj-b_f.ivp
# MIX06_MIX8821_ketr-a_f.ivp
# MIX06_MIX8821_kevg-a_f.ivp
# MIX06_MIX8821_keyb-a_f.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH12_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH12_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH06_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH09_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH06_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH11_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH13_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH11_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH03_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH09_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH03_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH06_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH07_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH10_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH11_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH02_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH11_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH02_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH10_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH04_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH09_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH03_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH06_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH04_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH02_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH05_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH08_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH13_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH08_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH08_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH04_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH03_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH04_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH07_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH05_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH05_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH13_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH11_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH09_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH08_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH13_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH02_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH02_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH13_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH03_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH04_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH07_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH06_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH12_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH10_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH07_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH06_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH10_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH12_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH08_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH12_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH11_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH03_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH04_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH07_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH09_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH07_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH10_m.ivp
# MIX08_MIX106453_20070412_170316_LDC_29123-CH05_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH09_m.ivp
# MIX08_MIX106453_20070405_164358_LDC_29123-CH05_m.ivp
# MIX08_MIX106453_20070402_162832_LDC_29123-CH12_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH10_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH05_m.ivp
# MIX08_MIX106453_20070412_154920_LDC_29123-CH02_m.ivp
# MIX08_MIX106453_20070402_152950_LDC_29123-CH08_m.ivp
# MIX08_MIX106453_20070405_154302_LDC_29123-CH13_m.ivp
# MIX08_MIX106453_ffmuw-a_m.ivp
# MIX08_MIX106453_tffkw-b_m.ivp
# MIX08_MIX106453_fkheh-a_m.ivp
# MIX08_MIX106453_fkwgw-a_m.ivp
# MIX08_MIX106453_fgesx-b_m.ivp
# MIX08_MIX106453_tojeo-b_m.ivp
# MIX08_MIX106453_tkwne-a_m.ivp
# MIX08_MIX106453_tjlbr-a_m.ivp
# MIX08_MIX106453_twjtz-a_m.ivp
# SWCELLP2_SW6419_45843-b_f.ivp
# SWCELLP2_SW6419_46968-b_f.ivp
# SWCELLP2_SW6419_47270-b_f.ivp
# SWCELLP2_SW6419_45549-b_f.ivp
# SWCELLP2_SW6419_47143-b_f.ivp
# SWCELLP2_SW6419_45621-b_f.ivp
# SWCELLP2_SW6419_46081-b_f.ivp
# SWCELLP2_SW6419_47078-b_f.ivp
# SWCELLP2_SW6419_46756-b_f.ivp
# SWCELLP2_SW6419_45417-b_f.ivp
# SWPH3_SW4977_30412-b_m.ivp
# SWPH3_SW4977_32348-a_m.ivp
# SWPH3_SW4977_30587-b_m.ivp
# SWPH3_SW4977_31623-b_m.ivp
# SWPH3_SW4977_31980-b_m.ivp
# SWPH3_SW4977_32100-a_m.ivp
# SWPH3_SW4977_32620-a_m.ivp
# SWPH3_SW4977_30268-b_m.ivp
# SWPH2_SW3572_22606-a_f.ivp
# SWPH2_SW3572_24205-a_f.ivp
# SWPH2_SW3572_21516-a_f.ivp
# SWPH2_SW3572_20318-b_f.ivp
# SWPH2_SW3572_20420-a_f.ivp
# SWPH2_SW3572_24095-b_f.ivp
# SWPH2_SW3572_21328-b_f.ivp
# SWPH2_SW3572_21220-b_f.ivp
# SWPH2_SW3572_22039-b_f.ivp
# SWPH2_SW3572_20351-b_f.ivp
# SWPH2_SW3572_20969-a_f.ivp
# SWPH2_SW3572_22508-a_f.ivp
# SWPH2_SW3572_20228-a_f.ivp
# SWPH2_SW3572_22921-a_f.ivp
# SWPH2_SW3572_24333-a_f.ivp
# SWPH2_SW3572_23810-a_f.ivp
# SWPH2_SW3572_20191-a_f.ivp
# SWPH2_SW3572_20707-b_f.ivp
# SWPH2_SW3572_24276-a_f.ivp
# SWPH2_SW3572_21976-a_f.ivp
# SWPH2_SW3572_24410-a_f.ivp
# MIX08_MIX111454_thbqk-b_f.ivp
# MIX08_MIX111454_traaq-b_f.ivp
# MIX08_MIX111454_thkqe-a_f.ivp
# MIX08_MIX111454_tzvws-a_f.ivp
# MIX08_MIX111454_tcpuy-b_f.ivp
# MIX08_MIX111454_tsgtt-a_f.ivp
# MIX08_MIX111454_tyqie-a_f.ivp
# MIX08_MIX111454_txfaw-a_f.ivp
# MIX06_MIX1970_jdcl-a_f.ivp
# MIX06_MIX1970_jhbc-a_f.ivp
# MIX06_MIX1970_jekf-a_f.ivp
# MIX06_MIX1970_jfcd-a_f.ivp
# MIX06_MIX1970_jguh-a_f.ivp
# MIX06_MIX1970_jgia-a_f.ivp
# MIX06_MIX1970_jcwk-a_f.ivp
# MIX06_MIX1970_jcpj-a_f.ivp
# MIX06_MIX101911_kdwu-b_f.ivp
# MIX06_MIX101911_kdgj-b_f.ivp
# MIX06_MIX101911_oank-b_f.ivp
# MIX06_MIX101911_kavd-b_f.ivp
# MIX06_MIX101911_kacb-b_f.ivp
# MIX06_MIX101911_ofqt-b_f.ivp
# MIX06_MIX101911_kcgq-b_f.ivp
# MIX06_MIX101911_odrj-a_f.ivp
# MIX06_MIX101911_ocxz-a_f.ivp
# MIX08_MIX101911_tllbz-b_f.ivp
# MIX06_MIX101911_oehs-a_f.ivp
# MIX06_MIX101911_ocjo-b_f.ivp
# MIX06_MIX101911_kaxc-b_f.ivp
# MIX06_MIX101911_oepz-b_f.ivp
# MIX06_MIX101911_kbdg-b_f.ivp
# MIX06_MIX101911_ognu-b_f.ivp
# MIX06_MIX101911_kdeg-b_f.ivp
# MIX06_MIX3655_peez-b_m.ivp
# MIX06_MIX3655_pbir-b_m.ivp
# MIX06_MIX3655_pdkf-b_m.ivp
# MIX06_MIX3655_pdic-b_m.ivp
# MIX06_MIX3655_pefz-b_m.ivp
# MIX06_MIX3655_pdtt-b_m.ivp
# MIX06_MIX3655_pckv-b_m.ivp
# MIX06_MIX3655_pbyi-b_m.ivp
# MIX06_MIX3655_pdxx-b_m.ivp
# MIX06_MIX3655_pdgg-b_m.ivp
# MIX06_MIX3655_pcgr-b_m.ivp
# MIX06_MIX3655_pety-b_m.ivp
# MIX06_MIX3655_pdwq-b_m.ivp
# MIX06_MIX3655_pczu-b_m.ivp
# MIX06_MIX3655_pely-b_m.ivp
# MIX06_MIX3655_peui-b_m.ivp
# MIX06_MIX3655_pbmk-b_m.ivp
# MIX06_MIX3655_pbkb-b_m.ivp
# MIX06_MIX3655_pdns-b_m.ivp
# MIX06_MIX3655_pcre-b_m.ivp
# MIX06_MIX3655_pdxg-b_m.ivp
# MIX06_MIX3655_pdme-b_m.ivp
# MIX06_MIX3655_pbzz-b_m.ivp
# MIX06_MIX3655_pcsw-b_m.ivp
# MIX06_MIX3655_pbpw-b_m.ivp
# MIX06_MIX3655_pazp-b_m.ivp
# MIX06_MIX3655_pbfc-b_m.ivp
# MIX06_MIX3655_pebu-b_m.ivp
# MIX06_MIX3655_pbta-b_m.ivp
# MIX06_MIX3655_pcli-b_m.ivp
# MIX06_MIX3655_paqz-b_m.ivp
# MIX06_MIX3655_pczz-b_m.ivp
# MIX06_MIX3655_kewo-b_m.ivp
# MIX06_MIX3655_oiym-b_m.ivp
# MIX06_MIX3655_oiwa-a_m.ivp
# MIX06_MIX3655_pfzv-b_m.ivp
# MIX06_MIX3655_oixu-a_m.ivp
# MIX06_MIX3655_pfuz-b_m.ivp
# MIX06_MIX3655_oisd-b_m.ivp
# MIX06_MIX3655_oixl-b_m.ivp
# MIX06_MIX3655_ojbf-a_m.ivp
# MIX06_MIX3655_oizy-a_m.ivp
# MIX06_MIX3655_pgmj-b_m.ivp
# MIX06_MIX3655_pgam-b_m.ivp
# MIX06_MIX3655_ojgp-b_m.ivp
# MIX06_MIX3655_pfye-b_m.ivp
# MIX06_MIX3655_oivv-b_m.ivp
# MIX06_MIX3655_oiyl-b_m.ivp
# MIX06_MIX3655_oiri-a_m.ivp
# MIX05_MIX6894_noqx-a_m.ivp
# MIX05_MIX6894_nkgg-a_m.ivp
# MIX05_MIX6894_nbtt-a_m.ivp
# MIX05_MIX6894_ngub-a_m.ivp
# MIX05_MIX6894_ngds-a_m.ivp
# MIX05_MIX6894_nbqv-a_m.ivp
# MIX05_MIX6894_nnud-a_m.ivp
# MIX05_MIX6894_nkey-a_m.ivp
# MIX05_MIX6894_nbsf-a_m.ivp
# MIX05_MIX6894_neeu-a_m.ivp
# MIX05_MIX6894_nfgu-a_m.ivp
# MIX05_MIX6894_nduo-a_m.ivp
# MIX05_MIX6894_ncwy-a_m.ivp
# MIX05_MIX6894_nens-a_m.ivp
# MIX05_MIX6894_njpu-a_m.ivp
# MIX05_MIX6894_napf-a_m.ivp
# MIX05_MIX6894_njdu-a_m.ivp
# MIX05_MIX6894_nltu-a_m.ivp
# MIX05_MIX6894_nhlu-a_m.ivp
# MIX05_MIX6894_nnxp-a_m.ivp
# MIX05_MIX6894_nfpl-a_m.ivp
# MIX05_MIX6894_navm-a_m.ivp
# MIX05_MIX6894_nayc-a_m.ivp
# MIX05_MIX6894_neod-a_m.ivp
# MIX05_MIX6894_neuy-a_m.ivp
# MIX08_MIX106132_tgtch-a_m.ivp
# MIX08_MIX106132_tucat-a_m.ivp
# MIX08_MIX106132_thvvx-b_m.ivp
# MIX08_MIX106132_tunil-b_m.ivp
# MIX08_MIX106132_ftcan-a_m.ivp
# MIX08_MIX106132_ttign-a_m.ivp
# MIX08_MIX106132_thlyf-a_m.ivp
# MIX08_MIX106132_fadxv-a_m.ivp
# MIX06_MIX102197_kcfl-b_m.ivp
# MIX06_MIX102197_ofdd-a_m.ivp
# MIX06_MIX102197_ofhh-b_m.ivp
# MIX06_MIX102197_ocyf-b_m.ivp
# MIX08_MIX102197_tooed-b_m.ivp
# MIX06_MIX102197_ohwx-b_m.ivp
# MIX06_MIX102197_kdzh-a_m.ivp
# MIX06_MIX102197_kell-a_m.ivp
# MIX06_MIX102197_odqa-a_m.ivp
# MIX06_MIX102197_kash-a_m.ivp
# MIX06_MIX102197_obrm-a_m.ivp
# MIX06_MIX102197_kdtw-b_m.ivp
# MIX06_MIX102197_keqj-a_m.ivp
# MIX06_MIX102197_kcld-a_m.ivp
# MIX06_MIX102197_kakz-a_m.ivp
# MIX06_MIX102197_oebj-a_m.ivp
# SWCELLP2_SW6456_46621-b_m.ivp
# SWCELLP2_SW6456_47161-b_m.ivp
# SWCELLP2_SW6456_45000-b_m.ivp
# SWCELLP2_SW6456_47398-b_m.ivp
# SWCELLP2_SW6456_47367-b_m.ivp
# SWCELLP2_SW6456_47176-b_m.ivp
# SWCELLP2_SW6456_47219-b_m.ivp
# SWCELLP2_SW6456_45165-b_m.ivp
# SWCELLP2_SW6456_45077-b_m.ivp
# SWCELLP2_SW6456_45106-b_m.ivp
# MIX05_MIX7777_nhkt-a_f.ivp
# MIX05_MIX7777_njaq-a_f.ivp
# MIX05_MIX7777_nguj-a_f.ivp
# MIX05_MIX7777_nhog-a_f.ivp
# MIX05_MIX7777_nmwq-a_f.ivp
# MIX05_MIX7777_nkpo-a_f.ivp
# MIX05_MIX7777_nmpw-a_f.ivp
# MIX05_MIX7777_nbjg-a_f.ivp
# MIX05_MIX7777_noax-a_f.ivp
# MIX05_MIX7777_nhsw-a_f.ivp
# MIX05_MIX7777_nixx-a_f.ivp
# MIX05_MIX7777_nhgp-a_f.ivp
# MIX05_MIX7777_nmjj-a_f.ivp
# MIX05_MIX7777_nkqc-a_f.ivp
# MIX05_MIX7777_naco-a_f.ivp
# MIX05_MIX7777_nehf-a_f.ivp
# MIX05_MIX7777_njek-a_f.ivp
# MIX05_MIX7777_ncqz-a_f.ivp
# MIX05_MIX7777_nohe-a_f.ivp
# MIX05_MIX7777_noqd-a_f.ivp
# MIX05_MIX7777_ngfz-a_f.ivp
# MIX05_MIX7777_nbso-a_f.ivp
# MIX05_MIX7777_nosf-a_f.ivp
# MIX05_MIX7777_nmmc-a_f.ivp
# MIX05_MIX7777_nmfg-a_f.ivp
# MIX05_MIX7777_ndqy-a_f.ivp
# MIX05_MIX7777_nfwx-a_f.ivp
# MIX05_MIX7777_ngtw-a_f.ivp
# MIX05_MIX7777_niqh-a_f.ivp
# MIX05_MIX7777_noii-a_f.ivp
# MIX05_MIX7777_nkup-a_f.ivp
# MIX05_MIX7777_nbbn-a_f.ivp
# MIX05_MIX7777_nlew-a_f.ivp
# MIX04_MIX7240_xbfg-x_m.ivp
# MIX04_MIX7240_tezw-x_m.ivp
# MIX04_MIX7240_tiuw-x_m.ivp
# MIX04_MIX7240_tikp-x_m.ivp
# MIX04_MIX7240_teuh-x_m.ivp
# MIX04_MIX7240_xexj-x_m.ivp
# MIX04_MIX7240_xept-x_m.ivp
# MIX04_MIX7240_tapw-x_m.ivp
# MIX04_MIX7240_tagl-x_m.ivp
# MIX04_MIX7240_taqd-x_m.ivp
# MIX04_MIX7240_thkk-x_m.ivp
# SWPH3_SW4109_32698-b_f.ivp
# SWPH3_SW4109_30941-a_f.ivp
# SWPH3_SW4109_30889-b_f.ivp
# SWPH3_SW4109_32064-a_f.ivp
# SWPH3_SW4109_32050-b_f.ivp
# SWPH3_SW4109_30589-a_f.ivp
# SWPH3_SW4109_31436-a_f.ivp
# SWPH3_SW4109_31953-a_f.ivp
# SWPH3_SW4109_32213-b_f.ivp
# SWPH3_SW4109_32087-b_f.ivp
# MIX08_MIX111092_thukf-b_f.ivp
# MIX08_MIX111092_tcbxi-a_f.ivp
# MIX08_MIX111092_tcvgv-b_f.ivp
# MIX08_MIX111092_tmrzk-b_f.ivp
# MIX08_MIX111092_txqhl-b_f.ivp
# MIX08_MIX111092_tlhjg-b_f.ivp
# MIX08_MIX111092_tygft-b_f.ivp
# MIX08_MIX111092_toofv-b_f.ivp
# MIX08_MIX111092_tnrdh-a_f.ivp
# MIX08_MIX111092_tckhb-a_f.ivp
# SWPH2_SW3601_24565-a_m.ivp
# SWPH2_SW3601_23435-b_m.ivp
# SWPH2_SW3601_23302-a_m.ivp
# SWPH2_SW3601_23605-a_m.ivp
# SWPH2_SW3601_22688-b_m.ivp
# SWPH2_SW3601_24209-b_m.ivp
# SWPH2_SW3601_20681-a_m.ivp
# SWPH2_SW3601_24382-b_m.ivp
# SWPH2_SW3601_20928-b_m.ivp
# SWPH2_SW3601_21692-b_m.ivp
# SWPH2_SW3601_23675-b_m.ivp
# SWPH2_SW3601_22094-b_m.ivp
# SWPH2_SW3601_20545-a_m.ivp
# SWPH3_SW4353_31894-a_f.ivp
# SWPH3_SW4353_30759-a_f.ivp
# SWPH3_SW4353_31405-a_f.ivp
# SWPH3_SW4353_30211-b_f.ivp
# SWPH3_SW4353_32229-b_f.ivp
# SWPH3_SW4353_30693-a_f.ivp
# SWPH3_SW4353_31103-b_f.ivp
# SWPH3_SW4353_30409-a_f.ivp
# SWPH3_SW4353_30880-a_f.ivp
# SWPH3_SW4353_31700-a_f.ivp
# SWPH3_SW4353_31448-a_f.ivp
# SWPH3_SW4353_32306-a_f.ivp
# SWPH3_SW4706_31143-a_f.ivp
# SWPH3_SW4706_30980-a_f.ivp
# SWPH3_SW4706_31720-b_f.ivp
# SWPH3_SW4706_31488-b_f.ivp
# SWPH3_SW4706_32322-b_f.ivp
# SWPH3_SW4706_30198-a_f.ivp
# SWPH3_SW4706_30719-a_f.ivp
# SWPH3_SW4706_32453-b_f.ivp
# SWPH3_SW4706_30037-b_f.ivp
# SWPH3_SW4706_30452-a_f.ivp
# SWPH3_SW4706_30546-a_f.ivp
# SWPH3_SW4706_30652-b_f.ivp
# SWPH3_SW4706_30552-a_f.ivp
# SWPH3_SW4706_31863-b_f.ivp
# SWPH3_SW4706_31061-a_f.ivp
# SWPH3_SW4706_31354-a_f.ivp
# SWPH3_SW4706_30774-a_f.ivp
# SWPH3_SW4706_32676-b_f.ivp
# MIX06_MIX103019_ogzf-a_m.ivp
# MIX08_MIX103019_tbbuy-b_m.ivp
# MIX08_MIX103019_tgint-b_m.ivp
# MIX08_MIX103019_tjkdl-b_m.ivp
# MIX06_MIX103019_kbsh-b_m.ivp
# MIX08_MIX103019_fewxu-a_m.ivp
# MIX08_MIX103019_tjrtu-b_m.ivp
# MIX08_MIX103019_timfj-b_m.ivp
# MIX08_MIX103019_fllch-b_m.ivp
# MIX08_MIX103019_tpjlj-b_m.ivp
# MIX08_MIX103019_tpfit-b_m.ivp
# MIX08_MIX103019_tlzpq-b_m.ivp
# MIX08_MIX103019_tpsde-a_m.ivp
# SWPH3_SW4990_32100-b_m.ivp
# SWPH3_SW4990_32067-b_m.ivp
# SWPH3_SW4990_32040-a_m.ivp
# SWPH3_SW4990_32444-b_m.ivp
# SWPH3_SW4990_32043-b_m.ivp
# SWPH3_SW4990_32155-a_m.ivp
# SWPH3_SW4990_32647-a_m.ivp
# SWPH3_SW4990_32167-b_m.ivp
# SWPH3_SW4522_30348-a_f.ivp
# SWPH3_SW4522_30081-a_f.ivp
# SWPH3_SW4522_31676-b_f.ivp
# SWPH3_SW4522_31256-b_f.ivp
# SWPH3_SW4522_30749-b_f.ivp
# SWPH3_SW4522_32194-a_f.ivp
# SWPH3_SW4522_30833-a_f.ivp
# SWPH3_SW4522_30178-a_f.ivp
# SWPH3_SW4522_31626-b_f.ivp
# SWPH3_SW4522_32506-a_f.ivp
# SWPH3_SW4522_31205-a_f.ivp
# SWPH3_SW4522_30430-a_f.ivp
# SWPH3_SW4522_32245-b_f.ivp
# MIX06_MIX7279_jfop-a_m.ivp
# MIX06_MIX7279_jdds-a_m.ivp
# MIX06_MIX7279_jczz-b_m.ivp
# MIX06_MIX7279_jgya-a_m.ivp
# MIX06_MIX7279_jhid-b_m.ivp
# MIX06_MIX7279_jbbg-a_m.ivp
# MIX06_MIX7279_jhnr-b_m.ivp
# MIX06_MIX7279_jhhy-a_m.ivp
# MIX08_MIX106659_fhbat-a_m.ivp
# MIX08_MIX106659_tfypc-b_m.ivp
# MIX08_MIX106659_tscao-b_m.ivp
# MIX08_MIX106659_fejen-b_m.ivp
# MIX08_MIX106659_tywko-b_m.ivp
# MIX08_MIX106659_fpjme-a_m.ivp
# MIX08_MIX106659_tfnqc-a_m.ivp
# MIX08_MIX106659_tjyjn-a_m.ivp
# MIX08_MIX106659_tuiue-b_m.ivp
# MIX08_MIX106659_fdxsl-a_m.ivp
# MIX08_MIX106659_fzejw-a_m.ivp
# MIX08_MIX106659_frifg-b_m.ivp
# FISHE1_FISHE7501_01571-a_f.ivp
# FISHE1_FISHE7501_02027-a_f.ivp
# FISHE1_FISHE7501_01955-a_f.ivp
# FISHE1_FISHE7501_01121-b_f.ivp
# MIX06_MIX3775_pgdy-a_m.ivp
# MIX06_MIX3775_pckx-b_m.ivp
# MIX06_MIX3775_pdvs-b_m.ivp
# MIX06_MIX3775_peci-b_m.ivp
# MIX06_MIX3775_pdjh-b_m.ivp
# MIX06_MIX3775_pamf-a_m.ivp
# MIX06_MIX3775_pckn-b_m.ivp
# MIX06_MIX3775_pdtf-b_m.ivp
# MIX06_MIX3775_pcap-b_m.ivp
# MIX06_MIX3775_pdcy-b_m.ivp
# MIX06_MIX3775_pdxd-b_m.ivp
# MIX06_MIX3775_peik-b_m.ivp
# MIX06_MIX3775_pcdx-a_m.ivp
# MIX06_MIX3775_pbwg-b_m.ivp
# MIX06_MIX3775_pbsa-a_m.ivp
# MIX06_MIX3775_pena-a_m.ivp
# MIX06_MIX3775_pbwu-b_m.ivp
# MIX06_MIX3775_pbvw-b_m.ivp
# MIX06_MIX3775_pegv-a_m.ivp
# MIX06_MIX3775_pfvd-b_m.ivp
# MIX06_MIX3775_pcwk-b_m.ivp
# MIX06_MIX3775_pchy-a_m.ivp
# MIX06_MIX3775_ojkl-b_m.ivp
# MIX06_MIX3775_pdlr-b_m.ivp
# MIX06_MIX3775_papp-a_m.ivp
# MIX06_MIX3775_pewn-a_m.ivp
# MIX06_MIX3775_peap-a_m.ivp
# MIX06_MIX3775_ojks-a_m.ivp
# MIX06_MIX3775_pdox-a_m.ivp
# MIX06_MIX3775_paiu-b_m.ivp
# MIX06_MIX3775_pbas-a_m.ivp
# MIX06_MIX3775_pakc-a_m.ivp
# MIX06_MIX3775_peqd-a_m.ivp
# MIX06_MIX3775_pcew-b_m.ivp
# MIX06_MIX3775_pcil-a_m.ivp
# MIX06_MIX3775_peph-a_m.ivp
# MIX06_MIX3775_pauj-a_m.ivp
# MIX06_MIX3775_pbqz-b_m.ivp
# MIX06_MIX3775_pcuk-b_m.ivp
# MIX06_MIX3775_pfrq-b_m.ivp
# MIX06_MIX3775_peae-b_m.ivp
# MIX06_MIX3775_pdkr-a_m.ivp
# MIX06_MIX3775_pcye-a_m.ivp
# MIX06_MIX3775_pdwk-a_m.ivp
# MIX06_MIX3775_pgel-a_m.ivp
# MIX06_MIX3775_pevw-a_m.ivp
# MIX06_MIX3775_pces-a_m.ivp
# MIX06_MIX3775_pedv-a_m.ivp
# MIX06_MIX3775_patq-a_m.ivp
# MIX06_MIX3775_pang-b_m.ivp
# MIX06_MIX3775_peki-a_m.ivp
# MIX06_MIX3775_pemq-b_m.ivp
# MIX06_MIX3775_peyr-b_m.ivp
# MIX06_MIX3775_kexc-b_m.ivp
# MIX06_MIX3775_kesp-a_m.ivp
# MIX06_MIX3775_kezl-b_m.ivp
# MIX06_MIX3775_keui-a_m.ivp
# MIX06_MIX3775_peic-b_m.ivp
# MIX06_MIX3775_oisc-a_m.ivp
# MIX06_MIX3775_kezj-b_m.ivp
# MIX06_MIX3775_kero-b_m.ivp
# MIX06_MIX3775_pfxu-b_m.ivp
# MIX06_MIX3775_keya-b_m.ivp
# MIX06_MIX3775_keyc-a_m.ivp
# MIX06_MIX3775_ojgp-a_m.ivp
# MIX06_MIX3775_ojid-b_m.ivp
# MIX06_MIX103090_obyb-a_f.ivp
# MIX06_MIX103090_ocms-b_f.ivp
# MIX06_MIX103090_katt-b_f.ivp
# MIX06_MIX103090_obka-a_f.ivp
# MIX06_MIX103090_kbfm-a_f.ivp
# MIX06_MIX103090_kdnz-a_f.ivp
# MIX06_MIX103090_oghs-a_f.ivp
# MIX06_MIX103090_kbrx-b_f.ivp
# MIX06_MIX100952_odts-a_m.ivp
# MIX06_MIX100952_kbhp-b_m.ivp
# MIX06_MIX100952_odmu-a_m.ivp
# MIX06_MIX100952_oigk-b_m.ivp
# MIX06_MIX100952_keoc-a_m.ivp
# MIX06_MIX100952_kcrg-a_m.ivp
# MIX06_MIX100952_kbir-a_m.ivp
# MIX06_MIX100952_oimt-a_m.ivp
# MIX06_MIX100952_kegh-a_m.ivp
# MIX06_MIX100952_oihi-a_m.ivp
# MIX06_MIX100952_kalp-a_m.ivp
# MIX06_MIX100952_kavi-b_m.ivp
# MIX06_MIX100952_kcrh-a_m.ivp
# MIX08_MIX100396_tpyrd-a_m.ivp
# MIX08_MIX100396_tqwjq-b_m.ivp
# MIX08_MIX100396_tirfp-a_m.ivp
# MIX08_MIX100396_tltcd-a_m.ivp
# MIX08_MIX100396_fxfef-a_m.ivp
# MIX08_MIX100396_tfkom-a_m.ivp
# MIX08_MIX100396_tycik-a_m.ivp
# MIX08_MIX100396_fkffz-a_m.ivp
# MIX08_MIX100396_tsorl-a_m.ivp
# MIX08_MIX100396_tjlzj-a_m.ivp
# MIX08_MIX100396_tgdts-a_m.ivp
# MIX05_MIX8232_naru-a_f.ivp
# MIX05_MIX8232_nfrr-a_f.ivp
# MIX06_MIX8232_jarv-b_f.ivp
# MIX06_MIX8232_jdrv-b_f.ivp
# MIX06_MIX8232_jeam-b_f.ivp
# MIX06_MIX8232_jcqh-b_f.ivp
# MIX06_MIX8232_jdup-a_f.ivp
# MIX06_MIX8232_jgem-a_f.ivp
# MIX06_MIX8232_jdjc-b_f.ivp
# MIX05_MIX8232_ncmu-a_f.ivp
# MIX06_MIX8232_jhvq-b_f.ivp
# MIX08_MIX106084_tddym-a_f.ivp
# MIX08_MIX106084_tpqpk-a_f.ivp
# MIX08_MIX106084_twocq-a_f.ivp
# MIX08_MIX106084_frnrn-b_f.ivp
# MIX08_MIX106084_twihh-b_f.ivp
# MIX08_MIX106084_fnoro-a_f.ivp
# MIX08_MIX106084_tnpgi-b_f.ivp
# MIX08_MIX106084_fjzgi-a_f.ivp
# MIX08_MIX106084_tnpge-b_f.ivp
# MIX08_MIX106084_tfdkq-a_f.ivp
# MIX08_MIX106084_tnpgg-a_f.ivp
# MIX08_MIX106084_fytzo-b_f.ivp
# MIX08_MIX106084_tgwnh-a_f.ivp
# MIX08_MIX106084_fhtti-a_f.ivp
# SWCELLP2_SW6733_47638-b_m.ivp
# SWCELLP2_SW6733_46041-b_m.ivp
# SWCELLP2_SW6733_47409-b_m.ivp
# SWCELLP2_SW6733_47606-b_m.ivp
# SWCELLP2_SW6733_45735-b_m.ivp
# SWCELLP2_SW6733_47295-b_m.ivp
# SWCELLP2_SW6733_45873-a_m.ivp
# SWPH2_SW3200_20102-b_f.ivp
# SWPH2_SW3200_20589-b_f.ivp
# SWPH2_SW3200_20463-a_f.ivp
# SWPH2_SW3200_21541-b_f.ivp
# SWPH2_SW3200_21020-b_f.ivp
# SWPH2_SW3200_21466-a_f.ivp
# SWPH2_SW3200_20133-a_f.ivp
# SWPH2_SW3200_21267-b_f.ivp
# SWPH2_SW3200_22309-b_f.ivp
# SWPH2_SW3200_20177-a_f.ivp
# SWPH2_SW3200_22184-a_f.ivp
# SWPH2_SW3200_20361-b_f.ivp
# SWPH2_SW3200_21943-b_f.ivp
# SWPH2_SW3200_20033-a_f.ivp
# SWPH2_SW3200_23123-b_f.ivp
# FISHE2_FISHE42343_10398-a_m.ivp
# FISHE2_FISHE42343_11168-b_m.ivp
# FISHE2_FISHE42343_10378-b_m.ivp
# FISHE2_FISHE42343_10414-a_m.ivp
# SWCELLP2_SW6525_45450-b_m.ivp
# SWCELLP2_SW6525_45650-b_m.ivp
# SWCELLP2_SW6525_46407-a_m.ivp
# SWCELLP2_SW6525_45974-b_m.ivp
# SWCELLP2_SW6525_45280-b_m.ivp
# SWCELLP2_SW6525_45106-a_m.ivp
# SWCELLP2_SW6525_46298-b_m.ivp
# SWCELLP2_SW6525_45373-a_m.ivp
# SWCELLP2_SW6525_46403-b_m.ivp
# SWCELLP2_SW6525_45705-b_m.ivp
# SWCELLP2_SW6525_46603-b_m.ivp
# SWCELLP2_SW6525_45827-b_m.ivp
# SWPH2_SW3484_20926-b_f.ivp
# SWPH2_SW3484_23641-b_f.ivp
# SWPH2_SW3484_22004-b_f.ivp
# SWPH2_SW3484_22224-a_f.ivp
# SWPH2_SW3484_22361-a_f.ivp
# SWPH2_SW3484_22803-b_f.ivp
# SWPH2_SW3484_24362-b_f.ivp
# SWPH2_SW3484_20672-b_f.ivp
# SWPH2_SW3484_21210-a_f.ivp
# SWPH2_SW3484_22611-b_f.ivp
# SWPH2_SW3484_20858-b_f.ivp
# SWPH2_SW3484_21639-a_f.ivp
# SWPH2_SW3484_21351-a_f.ivp
# MIX06_MIX101643_ogia-b_m.ivp
# MIX08_MIX101643_fbcue-b_m.ivp
# MIX06_MIX101643_obnc-b_m.ivp
# MIX08_MIX101643_tiknb-b_m.ivp
# MIX06_MIX101643_oelr-b_m.ivp
# MIX08_MIX101643_tgfui-b_m.ivp
# MIX08_MIX101643_fzvnw-b_m.ivp
# MIX06_MIX101643_kdvr-b_m.ivp
# MIX06_MIX101643_oecm-b_m.ivp
# SWCELLP2_SW6517_46315-b_f.ivp
# SWCELLP2_SW6517_47230-b_f.ivp
# SWCELLP2_SW6517_45925-b_f.ivp
# SWCELLP2_SW6517_46232-b_f.ivp
# SWCELLP2_SW6517_47173-b_f.ivp
# SWCELLP2_SW6517_46071-b_f.ivp
# SWCELLP2_SW6517_46757-b_f.ivp
# SWCELLP2_SW6517_47268-b_f.ivp
# SWCELLP2_SW6517_46439-b_f.ivp
# SWCELLP2_SW6517_46544-b_f.ivp
# MIX06_MIX101830_ocfd-a_m.ivp
# MIX06_MIX101830_kelx-a_m.ivp
# MIX06_MIX101830_oahl-a_m.ivp
# MIX06_MIX101830_kcdu-b_m.ivp
# MIX06_MIX101830_ohhh-a_m.ivp
# MIX06_MIX101830_ogfr-a_m.ivp
# MIX06_MIX101830_oiam-a_m.ivp
# MIX06_MIX101830_kaow-a_m.ivp
# MIX06_MIX101830_kdmr-b_m.ivp
# MIX06_MIX101830_kecs-b_m.ivp
# MIX06_MIX101830_katc-b_m.ivp
# MIX06_MIX101830_kdrc-a_m.ivp
# MIX06_MIX101830_kbvt-b_m.ivp
# MIX06_MIX101830_ohbz-b_m.ivp
# MIX06_MIX101830_ogws-a_m.ivp
# SWPH2_SW3477_23171-a_f.ivp
# SWPH2_SW3477_21950-b_f.ivp
# SWPH2_SW3477_21832-a_f.ivp
# SWPH2_SW3477_21143-b_f.ivp
# SWPH2_SW3477_20481-b_f.ivp
# SWPH2_SW3477_23287-b_f.ivp
# SWPH2_SW3477_20746-b_f.ivp
# SWPH2_SW3477_23473-a_f.ivp
# SWPH2_SW3477_21208-a_f.ivp
# SWPH2_SW3477_22756-b_f.ivp
# SWPH2_SW3477_20329-b_f.ivp
# SWPH2_SW3477_21451-b_f.ivp
# SWPH2_SW3477_22317-b_f.ivp
# SWPH2_SW3477_22581-b_f.ivp
# SWPH2_SW3477_22505-b_f.ivp
# SWPH2_SW3477_21268-b_f.ivp
# SWPH2_SW3477_20898-b_f.ivp
# SWPH2_SW3477_21636-a_f.ivp
# SWPH2_SW3477_21770-b_f.ivp
# SWPH2_SW3477_20409-b_f.ivp
# SWPH2_SW3477_24453-a_f.ivp
# SWPH2_SW3477_23530-b_f.ivp
# SWPH2_SW3477_20692-b_f.ivp
# MIX05_MIX5390_njtm-a_f.ivp
# MIX05_MIX5390_namj-a_f.ivp
# MIX05_MIX5390_nlqr-a_f.ivp
# MIX05_MIX5390_norz-b_f.ivp
# MIX05_MIX5390_ngdu-a_f.ivp
# MIX05_MIX5390_nmng-b_f.ivp
# ...
# MIX08_MIX110165_20070330_162721_LDC_79288-CH07_f.ivp
# MIX08_MIX110165_20070330_162721_LDC_79288-CH10_f.ivp
# MIX08_MIX110165_20070418_144707_LDC_79288-CH02_f.ivp
# MIX08_MIX110165_20070418_134217_LDC_79288-CH02_f.ivp
# MIX08_MIX110165_20070330_162721_LDC_79288-CH13_f.ivp
# MIX08_MIX110165_20070404_131912_LDC_79288-CH13_f.ivp
# MIX08_MIX110165_20070330_162721_LDC_79288-CH09_f.ivp
# MIX08_MIX110165_20070418_144707_LDC_79288-CH05_f.ivp
# MIX08_MIX110165_20070404_131912_LDC_79288-CH06_f.ivp
# MIX08_MIX110165_20070418_144707_LDC_79288-CH07_f.ivp
# MIX08_MIX110165_txjhh-a_f.ivp
# MIX08_MIX110165_twiex-a_f.ivp
# MIX08_MIX110165_tpghh-a_f.ivp
# MIX08_MIX110165_tkdgl-b_f.ivp
# MIX08_MIX110165_tjyyg-a_f.ivp
# MIX08_MIX110165_tcdmc-a_f.ivp
# MIX08_MIX110165_thzrp-a_f.ivp
# MIX08_MIX110165_tlmld-a_f.ivp
# MIX08_MIX110165_thlqd-b_f.ivp
# MIX08_MIX110165_fgjro-a_f.ivp
# MIX08_MIX104070_fmtkc-a_f.ivp
# MIX08_MIX104070_tubbx-b_f.ivp
# MIX08_MIX104070_tohza-a_f.ivp
# MIX08_MIX104070_fhhle-b_f.ivp
# MIX08_MIX104070_frufq-b_f.ivp
# MIX08_MIX104070_tvojr-b_f.ivp
# MIX08_MIX104070_taqru-b_f.ivp
# MIX08_MIX104070_tytuj-a_f.ivp
# MIX08_MIX104070_tnfsv-b_f.ivp
# MIX08_MIX104070_fcgeb-b_f.ivp
# MIX06_MIX7376_jfvz-b_f.ivp
# MIX06_MIX7376_jgjj-b_f.ivp
# MIX06_MIX7376_jblm-b_f.ivp
# MIX06_MIX7376_jbtf-b_f.ivp
# MIX06_MIX7376_jfdj-a_f.ivp
# MIX06_MIX7376_jhoq-b_f.ivp
# MIX06_MIX7376_jagu-b_f.ivp
# MIX06_MIX7376_jcsm-a_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH11_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH03_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH12_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH12_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH11_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH12_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH10_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH10_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH05_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH11_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH05_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH04_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH08_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH09_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH04_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH12_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH06_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH09_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH07_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH13_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH03_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH08_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH09_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH07_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH02_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH08_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH07_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH06_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH07_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH13_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH05_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH02_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH04_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH03_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH02_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH12_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH04_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH10_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH06_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH13_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH06_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH03_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH08_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH08_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH11_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH13_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH09_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH02_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH13_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH02_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH07_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH02_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH12_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH13_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH06_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH06_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH04_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH03_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH10_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH11_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH04_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH05_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH03_f.ivp
# MIX08_MIX111400_20071015_092940_ICSI_54428-CH05_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH10_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH07_f.ivp
# MIX08_MIX111400_20071031_120656_ICSI_54428-CH08_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH09_f.ivp
# MIX08_MIX111400_20071017_095450_ICSI_54428-CH11_f.ivp
# MIX08_MIX111400_20071017_085514_ICSI_54428-CH05_f.ivp
# MIX08_MIX111400_20071031_110421_ICSI_54428-CH09_f.ivp
# MIX08_MIX111400_20071015_103020_ICSI_54428-CH10_f.ivp
# MIX08_MIX111400_ttsdk-b_f.ivp
# MIX08_MIX111400_tupeb-b_f.ivp
# MIX08_MIX111400_tjgad-a_f.ivp
# MIX08_MIX111400_tdeus-a_f.ivp
# MIX08_MIX111400_tnrdl-b_f.ivp
# MIX08_MIX111400_tktmk-b_f.ivp
# MIX08_MIX111400_tzsas-a_f.ivp
# MIX08_MIX111400_torqc-b_f.ivp
# SWPH2_SW3362_20491-a_m.ivp
# SWPH2_SW3362_21728-a_m.ivp
# SWPH2_SW3362_21330-a_m.ivp
# SWPH2_SW3362_23444-b_m.ivp
# SWPH2_SW3362_20771-b_m.ivp
# SWPH2_SW3362_24485-b_m.ivp
# SWPH2_SW3362_21551-b_m.ivp
# SWPH2_SW3362_21166-b_m.ivp
# SWPH2_SW3362_22710-b_m.ivp
# SWPH2_SW3362_23725-b_m.ivp
# SWPH2_SW3362_22034-b_m.ivp
# FISHE2_FISHE78555_09685-a_m.ivp
# FISHE2_FISHE78555_09159-b_m.ivp
# FISHE2_FISHE78555_09549-a_m.ivp
# FISHE2_FISHE78555_11083-a_m.ivp
# MIX08_MIX103455_fkhet-b_m.ivp
# MIX08_MIX103455_tsjxf-b_m.ivp
# MIX08_MIX103455_txlrp-b_m.ivp
# MIX08_MIX103455_tsjed-b_m.ivp
# MIX08_MIX103455_tvaks-b_m.ivp
# MIX08_MIX103455_tpwjc-b_m.ivp
# MIX08_MIX103455_frega-a_m.ivp
# MIX08_MIX103455_ftwbh-a_m.ivp
# SWPH2_SW3521_23789-b_f.ivp
# SWPH2_SW3521_20666-a_f.ivp
# SWPH2_SW3521_21231-b_f.ivp
# SWPH2_SW3521_22065-b_f.ivp
# SWPH2_SW3521_22200-b_f.ivp
# SWPH2_SW3521_23184-b_f.ivp
# MIX05_MIX2425_nkqn-a_m.ivp
# MIX05_MIX2425_nign-b_m.ivp
# MIX05_MIX2425_ndvk-b_m.ivp
# MIX06_MIX2425_jipa-b_m.ivp
# MIX06_MIX2425_jddu-b_m.ivp
# MIX06_MIX2425_jigy-b_m.ivp
# MIX06_MIX2425_jbrt-b_m.ivp
# MIX05_MIX2425_nbrm-b_m.ivp
# MIX06_MIX2425_japw-b_m.ivp
# MIX06_MIX2425_jeeq-a_m.ivp
# MIX05_MIX2425_nchv-b_m.ivp
# MIX06_MIX2425_jcmj-b_m.ivp
# MIX06_MIX2425_jdum-b_m.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH09_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH04_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH06_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH06_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH05_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH02_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH05_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH10_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH08_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH05_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH06_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH11_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH11_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH11_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH07_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH07_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH03_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH09_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH09_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH11_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH09_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH03_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH13_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH12_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH13_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH06_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH04_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH09_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH12_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH10_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH07_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH02_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH10_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH05_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH07_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH08_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH08_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH12_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH04_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH07_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH02_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH03_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH02_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH05_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH11_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH04_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH06_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH07_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH02_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH09_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH10_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH12_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH13_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH13_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH03_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH11_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH12_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH10_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH04_f.ivp
# MIX08_MIX111506_20071022_195416_ICSI_88341-CH10_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH08_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH05_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH12_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH08_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH13_f.ivp
# MIX08_MIX111506_20071112_153624_ICSI_88341-CH03_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH08_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH03_f.ivp
# MIX08_MIX111506_20071022_190116_ICSI_88341-CH13_f.ivp
# MIX08_MIX111506_20071210_191140_ICSI_88341-CH06_f.ivp
# MIX08_MIX111506_20071112_141804_ICSI_88341-CH04_f.ivp
# MIX08_MIX111506_20071214_132901_ICSI_88341-CH02_f.ivp
# MIX08_MIX111506_tvkuv-a_f.ivp
# MIX08_MIX111506_thkql-a_f.ivp
# MIX08_MIX111506_ftxnf-a_f.ivp
# MIX08_MIX111506_fgpoj-a_f.ivp
# MIX08_MIX111506_fhkmo-b_f.ivp
# MIX08_MIX111506_ttfyu-b_f.ivp
# MIX08_MIX111506_tnoaz-a_f.ivp
# MIX08_MIX111506_fdzcn-a_f.ivp
# MIX08_MIX111506_teram-a_f.ivp
# MIX08_MIX111506_tstwk-a_f.ivp
# MIX06_MIX103031_ohbd-b_m.ivp
# MIX06_MIX103031_kdtb-a_m.ivp
# MIX06_MIX103031_ohah-b_m.ivp
# MIX06_MIX103031_oano-a_m.ivp
# MIX06_MIX103031_obih-b_m.ivp
# MIX06_MIX103031_kcns-a_m.ivp
# MIX06_MIX103031_kdqt-a_m.ivp
# MIX06_MIX103031_oeik-a_m.ivp
# MIX06_MIX103031_kccg-b_m.ivp
# MIX06_MIX103031_oeka-a_m.ivp
# MIX06_MIX103031_kdwk-a_m.ivp
# MIX06_MIX103031_kavu-a_m.ivp
# MIX06_MIX103031_kedp-a_m.ivp
# MIX06_MIX103031_oglk-a_m.ivp
# MIX06_MIX103031_kbyz-a_m.ivp
# MIX06_MIX103031_ogke-b_m.ivp
# MIX08_MIX103031_tqrgt-a_m.ivp
# SWPH2_SW3773_20707-a_m.ivp
# SWPH2_SW3773_23319-a_m.ivp
# SWPH2_SW3773_23631-a_m.ivp
# SWPH2_SW3773_20813-a_m.ivp
# SWPH2_SW3773_22938-a_m.ivp
# SWPH2_SW3773_21132-a_m.ivp
# SWPH2_SW3773_23202-a_m.ivp
# SWPH2_SW3773_23069-a_m.ivp
# MIX04_MIX6446_tdrx-x_m.ivp
# MIX04_MIX6446_xbgv-x_m.ivp
# MIX04_MIX6446_tgdx-x_m.ivp
# MIX04_MIX6446_tizo-x_m.ivp
# MIX04_MIX6446_takb-x_m.ivp
# MIX04_MIX6446_tfyl-x_m.ivp
# MIX04_MIX6446_tcqk-x_m.ivp
# MIX04_MIX6446_xasy-x_m.ivp
# MIX04_MIX6446_taun-x_m.ivp
# MIX04_MIX6446_teum-x_m.ivp
# MIX04_MIX6446_xbki-x_m.ivp
# MIX04_MIX6446_tbhi-x_m.ivp
# MIX04_MIX6446_tfmf-x_m.ivp
# MIX04_MIX6446_tevi-x_m.ivp
# MIX04_MIX6446_tioi-x_m.ivp
# MIX04_MIX6446_tdeh-x_m.ivp
# MIX04_MIX6446_taoh-x_m.ivp
# MIX04_MIX6446_tcka-x_m.ivp
# MIX04_MIX6446_tdct-x_m.ivp
# MIX08_MIX109136_tdkib-b_m.ivp
# MIX08_MIX109136_fbluw-a_m.ivp
# MIX08_MIX109136_tctfi-a_m.ivp
# MIX08_MIX109136_tdcjs-b_m.ivp
# MIX08_MIX109136_tsitu-b_m.ivp
# MIX08_MIX109136_txuzx-b_m.ivp
# MIX08_MIX109136_tbltm-b_m.ivp
# MIX08_MIX109136_tfkpj-b_m.ivp
# MIX08_MIX109136_tdcjr-b_m.ivp
# SWPH3_SW4388_32613-b_m.ivp
# SWPH3_SW4388_32175-b_m.ivp
# SWPH3_SW4388_31634-a_m.ivp
# SWPH3_SW4388_31704-a_m.ivp
# MIX08_MIX106987_torbi-b_f.ivp
# MIX08_MIX106987_fkopr-b_f.ivp
# MIX08_MIX106987_tgnlc-a_f.ivp
# MIX08_MIX106987_tkuah-a_f.ivp
# MIX08_MIX106987_ttigf-b_f.ivp
# MIX08_MIX106987_thyee-a_f.ivp
# MIX08_MIX106987_tauoe-b_f.ivp
# MIX08_MIX106987_tlmtw-b_f.ivp
# MIX08_MIX106987_tibrn-b_f.ivp
# MIX08_MIX106987_fgzsv-b_f.ivp
# MIX08_MIX106987_tnlqw-a_f.ivp
# MIX08_MIX106987_trgvy-b_f.ivp
# SWPH3_SW4883_31783-a_m.ivp
# SWPH3_SW4883_32347-b_m.ivp
# SWPH3_SW4883_32009-b_m.ivp
# SWPH3_SW4883_32450-a_m.ivp
# SWPH3_SW4883_32036-b_m.ivp
# SWPH3_SW4883_32522-a_m.ivp
# SWPH3_SW4883_32138-b_m.ivp
# SWPH3_SW4883_31857-a_m.ivp
# SWPH3_SW4883_32571-a_m.ivp
# MIX08_MIX105424_twzmu-b_f.ivp
# MIX08_MIX105424_tbpey-a_f.ivp
# MIX08_MIX105424_tfdkd-b_f.ivp
# MIX08_MIX105424_tvtyn-b_f.ivp
# MIX08_MIX105424_fcyal-a_f.ivp
# MIX08_MIX105424_fjruv-a_f.ivp
# MIX08_MIX105424_tkklp-a_f.ivp
# MIX08_MIX105424_tfpew-b_f.ivp
# MIX08_MIX105424_frmxg-b_f.ivp
# MIX08_MIX105424_fejec-b_f.ivp
# MIX08_MIX105424_fxehw-b_f.ivp
# MIX08_MIX105424_tgywd-a_f.ivp
# SWPH2_SW3144_20152-b_f.ivp
# SWPH2_SW3144_23312-b_f.ivp
# SWPH2_SW3144_23655-b_f.ivp
# SWPH2_SW3144_23689-b_f.ivp
# SWPH2_SW3144_20458-a_f.ivp
# SWPH2_SW3144_20128-a_f.ivp
# SWPH2_SW3144_21593-a_f.ivp
# SWPH2_SW3144_22484-b_f.ivp
# SWPH2_SW3144_24369-b_f.ivp
# SWPH2_SW3144_20354-a_f.ivp
# SWPH2_SW3144_20207-a_f.ivp
# SWPH2_SW3144_24311-b_f.ivp
# SWPH2_SW3144_20595-a_f.ivp
# SWPH2_SW3144_20024-a_f.ivp
# SWPH2_SW3144_20840-a_f.ivp
# SWPH2_SW3904_22543-a_m.ivp
# SWPH2_SW3904_22293-a_m.ivp
# SWPH2_SW3904_22893-b_m.ivp
# SWPH2_SW3904_22852-a_m.ivp
# SWPH2_SW3904_23307-b_m.ivp
# SWPH2_SW3904_22373-b_m.ivp
# SWPH2_SW3904_22218-b_m.ivp
# SWPH2_SW3904_22440-b_m.ivp
# SWPH2_SW3904_22428-a_m.ivp
# SWCELLP2_SW6235_45390-b_f.ivp
# SWCELLP2_SW6235_45257-b_f.ivp
# SWCELLP2_SW6235_45187-a_f.ivp
# SWCELLP2_SW6235_46086-b_f.ivp
# SWCELLP2_SW6235_45048-a_f.ivp
# SWCELLP2_SW6235_45690-a_f.ivp
# SWCELLP1_SW5365_40009-b_f.ivp
# SWCELLP1_SW5365_40111-b_f.ivp
# SWCELLP1_SW5365_40176-b_f.ivp
# SWCELLP1_SW5365_40006-b_f.ivp
# SWPH3_SW4112_30140-a_f.ivp
# SWPH3_SW4112_31497-a_f.ivp
# SWPH3_SW4112_31948-a_f.ivp
# SWPH3_SW4112_31673-b_f.ivp
# SWPH3_SW4112_31224-b_f.ivp
# SWPH3_SW4112_32474-a_f.ivp
# SWPH3_SW4112_31879-a_f.ivp
# SWPH3_SW4112_30825-b_f.ivp
# MIX08_MIX106164_tzxhn-a_f.ivp
# MIX08_MIX106164_tlssz-b_f.ivp
# MIX08_MIX106164_tvort-b_f.ivp
# MIX08_MIX106164_tkgiu-b_f.ivp
# MIX08_MIX106164_twqir-a_f.ivp
# MIX08_MIX106164_fgqfn-b_f.ivp
# MIX08_MIX106164_tdndp-b_f.ivp
# MIX08_MIX106164_thnhm-b_f.ivp
# SWCELLP2_SW6764_46584-b_f.ivp
# SWCELLP2_SW6764_47263-b_f.ivp
# SWCELLP2_SW6764_47321-b_f.ivp
# SWCELLP2_SW6764_47438-b_f.ivp
# SWCELLP2_SW6764_46512-a_f.ivp
# SWCELLP2_SW6764_47399-b_f.ivp
# MIX06_MIX102982_kcbh-a_f.ivp
# MIX06_MIX102982_oaip-b_f.ivp
# MIX06_MIX102982_oehh-b_f.ivp
# MIX06_MIX102982_ocio-a_f.ivp
# MIX06_MIX102982_ofno-b_f.ivp
# MIX06_MIX102982_kcha-b_f.ivp
# MIX06_MIX102982_kacy-a_f.ivp
# MIX08_MIX102982_ffgoe-b_f.ivp
# MIX06_MIX102982_obgi-b_f.ivp
# MIX06_MIX102982_kdvs-b_f.ivp
# MIX08_MIX102982_thhtz-a_f.ivp
# MIX08_MIX102982_fmbbc-b_f.ivp
# MIX06_MIX102982_kaqo-b_f.ivp
# MIX06_MIX102982_kcxi-b_f.ivp
# MIX06_MIX102982_kdrt-b_f.ivp
# MIX06_MIX102982_ocpd-b_f.ivp
# MIX06_MIX102982_kapx-b_f.ivp
# MIX06_MIX101310_kakg-b_f.ivp
# MIX06_MIX101310_kajd-b_f.ivp
# MIX06_MIX101310_ohzs-b_f.ivp
# MIX06_MIX101310_kcon-a_f.ivp
# MIX06_MIX101310_ohlo-b_f.ivp
# MIX06_MIX101310_ocpt-a_f.ivp
# MIX06_MIX101310_obnh-b_f.ivp
# MIX06_MIX101310_kakl-b_f.ivp
# MIX06_MIX101310_kaag-b_f.ivp
# MIX06_MIX101310_kdyl-b_f.ivp
# MIX06_MIX101310_kdff-a_f.ivp
# MIX06_MIX101310_ofce-a_f.ivp
# MIX06_MIX101310_ofwz-a_f.ivp
# MIX06_MIX101310_obag-a_f.ivp
# MIX06_MIX101310_oaje-b_f.ivp
# MIX06_MIX101310_kala-b_f.ivp

# %%
reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
run ivec_dae.py config/ivec_dae.config
# Out:
# weight folder exits
#
# logs folder exists
# Building network ...
# Trainable Model Parameters
# ----------------------------------------
# (W, (400, 100))
# (b, (100,))
# (W, (100, 100))
# (b, (100,))
# (W, (100, 400))
# (b, (400,))
# ----------------------------------------
# Starting training...
# Epoch 1 of 3 took 0.086s
#   training loss:		1.319932
#   validation loss:		0.979781
# Epoch 2 of 3 took 0.075s
#   training loss:		1.035115
#   validation loss:		0.985708
# Epoch 3 of 3 took 0.073s
#   training loss:		0.994691
#   validation loss:		0.980856
# Saving Model ...

# %%
# %%writefile rsr_multitask.py
import htkmfc
import os
import lasagne
import time
import theano
import theano.tensor as T
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import cPickle
import sys
import subprocess 

from fuel.datasets import IndexableDataset
from fuel.schemes import ShuffledScheme, SequentialScheme
from fuel.streams import DataStream

from collections import OrderedDict
import h5py

from fuel.datasets import H5PYDataset
from fuel.converters.base import fill_hdf5_file
from utils import load_data

cFile = sys.argv[1]

f=open(cFile)
lines = f.readlines()
lines = [l.strip() for l in lines]
values = [v.split()[1] for v in lines]


N_HIDDEN = int(values[0])
F_DIM = int(values[1])
LEARNING_RATE = np.cast['float32'](values[2])
BATCH_SIZE = int(values[3])
NUM_EPOCHS = int(values[4])
NUM_SPEAKERS = int(values[5])
NUM_PHRASES = int(values[6])
MODEL_NAME = values[7]
SAVE_PATH = values[8]
#data
TRAIN_FILE = values[9]
VALID_FILE = values[10]
SCRIPT = values[11]
MSC = values[12]

wtspth =os.path.join(SAVE_PATH,MODEL_NAME,'weights')
logpth =os.path.join(SAVE_PATH,MODEL_NAME,'logs')

#create a folder for logs and weights
if os.path.exists(wtspth):
    print 'weight folder exits\n'
else:
    Command1 = "mkdir -p" +" "+ wtspth
    process = subprocess.check_call(Command1.split())

if os.path.exists(logpth):
    print 'logs folder exists'
else:
    Command2 = "mkdir -p" +" "+ logpth
    process2 = subprocess.check_call(Command2.split())



# Min/max sequence length
MAX_LENGTH = 800

def build_rnn(net_input=None, mask_input=None):

    print("Building network ...")

    l_in = lasagne.layers.InputLayer(shape=(None, MAX_LENGTH, F_DIM), input_var = net_input)
    n_batch,_,_ = l_in.input_var.shape
    #print lasagne.layers.get_output(l_in, inputs={l_in: X}).eval({X: x_dummy}).shape

    l_mask = lasagne.layers.InputLayer(shape=(None, MAX_LENGTH), input_var = mask_input)
    #print lasagne.layers.get_output(l_mask, inputs={l_mask: Mask}).eval({Mask: mask}).shape

    #initialize the gates
    gate_parameters = lasagne.layers.recurrent.Gate(
    W_in=lasagne.init.Orthogonal(), W_hid=lasagne.init.Orthogonal(),
    b=lasagne.init.Constant(0.))
    
    cell_parameters = lasagne.layers.recurrent.Gate(
    W_in=lasagne.init.Orthogonal(), W_hid=lasagne.init.Orthogonal(),
    W_cell=None, b=lasagne.init.Constant(0.),nonlinearity=lasagne.nonlinearities.tanh)
    

    l_forward = lasagne.layers.LSTMLayer(l_in, N_HIDDEN, mask_input=l_mask,
                                         precompute_input=True, peepholes=True, 
                                         learn_init=True, only_return_final=True)
        
    
    l_backward = lasagne.layers.LSTMLayer(l_in, N_HIDDEN, mask_input=l_mask,
                                         precompute_input=True, peepholes=True, 
                                         learn_init=True, only_return_final=True, backwards=True)
    
    
    
    l_sum = lasagne.layers.ElemwiseSumLayer([l_forward, l_backward])

    l_spk_softmax = lasagne.layers.DenseLayer(l_sum, num_units=NUM_SPEAKERS, nonlinearity=lasagne.nonlinearities.softmax)

    l_phr_softmax = lasagne.layers.DenseLayer(l_sum, num_units=NUM_PHRASES, nonlinearity=lasagne.nonlinearities.softmax)
    
    return l_spk_softmax, l_phr_softmax


#print lasagne.layers.get_output(l_softmax, inputs={l_in: X, l_mask: Mask}).eval({X: d1, Mask: m1}).shape
#l_softmax = lasagne.layers.ReshapeLayer(l_dense, (n_batch, MAX_LENGTH, N_HIDDEN))

def main():
        
    X = T.tensor3(name='input',dtype='float32')
    MASK = T.matrix(name = 'mask', dtype='float32')
    SPK_LABELS = T.ivector(name='spk_labels')
    PHR_LABELS = T.ivector(name='phr_labels')

    #load data
    train_set = H5PYDataset(TRAIN_FILE,  which_sets=('train',))
    valid_set = H5PYDataset(TRAIN_FILE, which_sets=('test',))

    spk_network, phr_network = build_rnn(net_input=X, mask_input= MASK)
    
    network_output_spk = lasagne.layers.get_output(spk_network)
    network_output_phr = lasagne.layers.get_output(phr_network)

    val_prediction_spk = lasagne.layers.get_output(spk_network, deterministic=True)
    val_prediction_phr = lasagne.layers.get_output(phr_network, deterministic=True)
    #needed for accuracy
    
    val_acc_spk = T.mean(T.eq(T.argmax(val_prediction_spk, axis=1), SPK_LABELS), dtype=theano.config.floatX)
    val_acc_phr = T.mean(T.eq(T.argmax(val_prediction_phr, axis=1), PHR_LABELS), dtype=theano.config.floatX)

    #training accuracy
    train_acc_spk = T.mean(T.eq(T.argmax(network_output_spk, axis=1), SPK_LABELS), dtype=theano.config.floatX)
    train_acc_phr = T.mean(T.eq(T.argmax(network_output_phr, axis=1), PHR_LABELS), dtype=theano.config.floatX)
    
    #cost function    
    spk_cost = lasagne.objectives.categorical_crossentropy(network_output_spk, SPK_LABELS)
    phr_cost = lasagne.objectives.categorical_crossentropy(network_output_phr, PHR_LABELS)
    total_cost = spk_cost + phr_cost
    mean_cost = total_cost.mean()
    
    #Validation cost
    val_spk_cost = lasagne.objectives.categorical_crossentropy(val_prediction_spk, SPK_LABELS)
    val_phr_cost = lasagne.objectives.categorical_crossentropy(val_prediction_phr, PHR_LABELS)
    val_cost = val_spk_cost + val_phr_cost
    val_mcost = val_cost.mean()

    #Get parameters of both encoder and decoder
    all_parameters = lasagne.layers.get_all_params([spk_network, phr_network], trainable=True)

    print("Trainable Model Parameters")
    print("-"*40)
    for param in all_parameters:
        print(param, param.get_value().shape)
    print("-"*40)
    #add grad clipping to avoid exploding gradients
    all_grads = [T.clip(g,-3,3) for g in T.grad(mean_cost, all_parameters)]
    #all_grads = lasagne.updates.total_norm_constraint(all_grads,3)

    updates = lasagne.updates.adam(all_grads, all_parameters, learning_rate=LEARNING_RATE)

    train_func = theano.function([X, MASK, SPK_LABELS, PHR_LABELS], [mean_cost, train_acc_spk, train_acc_phr], updates=updates)

    val_func = theano.function([X, MASK, SPK_LABELS, PHR_LABELS], [val_mcost, val_acc_spk, val_acc_phr])

    trainerr=[]
    epoch=0 #set the epoch counter
    
    min_val_loss = np.inf
    max_val = np.inf*(-1)
    
    patience=0
    
    print("Starting training...")
        # We iterate over epochs:
    while 'true':
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        tr_acc_spk = 0
        tr_acc_phr = 0

        train_batches = 0

        h1=train_set.open()
        h2=valid_set.open()

        scheme = ShuffledScheme(examples=train_set.num_examples, batch_size=BATCH_SIZE)
        scheme1 = SequentialScheme(examples=valid_set.num_examples, batch_size=32)


        train_stream = DataStream(dataset=train_set, iteration_scheme=scheme)
        valid_stream = DataStream(dataset=valid_set, iteration_scheme=scheme1)

        start_time = time.time()

        for data in train_stream.get_epoch_iterator():
            t_data, t_mask, t_plabs,_, t_labs,_ = data
            terr, tacc_spk, tacc_phr = train_func(t_data, t_mask, t_labs, t_plabs)
            train_err += terr
            
            tr_acc_spk += tacc_spk
            tr_acc_phr += tacc_phr
            
            train_batches += 1

        val_err = 0
        val_acc_spk = 0
        val_acc_phr = 0
        
        val_batches = 0

        for data in valid_stream.get_epoch_iterator():
            v_data, v_mask, v_ptars, _, v_tars, _ = data
            err, acc_spk, acc_phr = val_func(v_data, v_mask ,v_tars, v_ptars)
            val_err += err
            val_acc_spk += acc_spk
            val_acc_phr += acc_phr
            
            val_batches += 1

        trainerr.append(train_err/train_batches)

        epoch+=1
        train_set.close(h1)
        valid_set.close(h2)
        
        #Display
        if display:
            
            print("Epoch {} of {} took {:.3f}s".format(
            epoch, NUM_EPOCHS, time.time() - start_time))
            print("  training loss:\t\t{:.6f}".format(train_err / train_batches))
            print("  training accuracy (speaker):\t\t{:.2f} %".format(
                tr_acc_spk / train_batches * 100))
            print("  training accuracy (phrase):\t\t{:.2f} %".format(
                tr_acc_phr / train_batches * 100))
            print("  validation loss:\t\t{:.6f}".format(val_err / val_batches))
            print("  validation accuracy (speaker):\t\t{:.2f} %".format(
                val_acc_spk / val_batches * 100))
            print("  validation accuracy (phrase):\t\t{:.2f} %".format(
                val_acc_phr / val_batches * 100))

        logfile = os.path.join(SAVE_PATH,MODEL_NAME,'logs',MODEL_NAME+'.log')
        flog1 = open(logfile,'ab')
        flog1.write("Running %s on %s" % (SCRIPT,MSC))
        flog1.write("Epoch {} of {} took {:.3f}s \n".format(
        epoch, NUM_EPOCHS, time.time() - start_time))
        flog1.write("  training loss:\t\t{:.6f}\n".format(train_err / train_batches))
        flog1.write("  training accuracy (speaker):\t\t{:.2f} %\n".format(
            tr_acc_spk / train_batches * 100))
        flog1.write("  training accuracy (phrase):\t\t{:.2f} %\n".format(
            tr_acc_phr / train_batches * 100))
        flog1.write("  validation loss:\t\t{:.6f}".format(val_err / val_batches))
        flog1.write("  validation accuracy (speaker):\t\t{:.2f} %\n".format(
            val_acc_spk / val_batches * 100))
        flog1.write("  validation accuracy (phrase):\t\t{:.2f} %\n".format(
            val_acc_phr / val_batches * 100))
        
        flog1.write("\n")
        flog1.close()

        if epoch == NUM_EPOCHS:
            break
 
        valE = val_err/val_batches
        
        if valE <= min_val_loss:

            model_params1 = lasagne.layers.get_all_param_values([spk_network, phr_network])

            model1_name = MODEL_NAME+'_minloss' + '.pkl'

            vpth1 = os.path.join(SAVE_PATH, MODEL_NAME, 'weights',model1_name)

            fsave = open(vpth1,'wb')  

            cPickle.dump(model_params1, fsave, protocol=cPickle.HIGHEST_PROTOCOL)

            fsave.close()

            min_val_loss = valE

        #Patience / Early stopping
        else:
            patience+=1
        
        if patience==10:
            break
            
    #Save the final model

    print('Saving Model ...')
    model_params = lasagne.layers.get_all_param_values([spk_network, phr_network])
    model1_name = MODEL_NAME+'_final' + '.pkl'
    vpth = os.path.join(SAVE_PATH, MODEL_NAME,'weights',model1_name)
    fsave = open(vpth,'wb')  
    cPickle.dump(model_params, fsave, protocol=cPickle.HIGHEST_PROTOCOL)
    fsave.close()
    
if __name__ == '__main__':
    main()
# Out:
# Overwriting rsr_multitask.py

# %%
run rsr_multitask.py config/rsr_multitask.config
# Out:
# weight folder exits
#
# logs folder exists
# Building network ...
# Trainable Model Parameters
# ----------------------------------------
# (W_in_to_ingate, (40, 50))
# (W_hid_to_ingate, (50, 50))
# (b_ingate, (50,))
# (W_in_to_forgetgate, (40, 50))
# (W_hid_to_forgetgate, (50, 50))
# (b_forgetgate, (50,))
# (W_in_to_cell, (40, 50))
# (W_hid_to_cell, (50, 50))
# (b_cell, (50,))
# (W_in_to_outgate, (40, 50))
# (W_hid_to_outgate, (50, 50))
# (b_outgate, (50,))
# (W_cell_to_ingate, (50,))
# (W_cell_to_forgetgate, (50,))
# (W_cell_to_outgate, (50,))
# (cell_init, (1, 50))
# (hid_init, (1, 50))
# (W_in_to_ingate, (40, 50))
# (W_hid_to_ingate, (50, 50))
# (b_ingate, (50,))
# (W_in_to_forgetgate, (40, 50))
# (W_hid_to_forgetgate, (50, 50))
# (b_forgetgate, (50,))
# (W_in_to_cell, (40, 50))
# (W_hid_to_cell, (50, 50))
# (b_cell, (50,))
# (W_in_to_outgate, (40, 50))
# (W_hid_to_outgate, (50, 50))
# (b_outgate, (50,))
# (W_cell_to_ingate, (50,))
# (W_cell_to_forgetgate, (50,))
# (W_cell_to_outgate, (50,))
# (cell_init, (1, 50))
# (hid_init, (1, 50))
# (W, (50, 194))
# (b, (194,))
# (W, (50, 30))
# (b, (30,))
# ----------------------------------------
# Starting training...
# Epoch 1 of 3 took 10.468s
#   training loss:		8.708508
#   training accuracy (speaker):		0.63 %
#   training accuracy (phrase):		5.18 %
#   validation loss:		8.623956
#   validation accuracy (speaker):		0.00 %
#   validation accuracy (phrase):		6.25 %
# Epoch 2 of 3 took 10.420s
#   training loss:		8.518374
#   training accuracy (speaker):		0.90 %
#   training accuracy (phrase):		12.23 %
#   validation loss:		8.536782
#   validation accuracy (speaker):		0.00 %
#   validation accuracy (phrase):		7.81 %
# Epoch 3 of 3 took 10.428s
#   training loss:		8.379722
#   training accuracy (speaker):		1.41 %
#   training accuracy (phrase):		19.88 %
#   validation loss:		8.453432
#   validation accuracy (speaker):		0.00 %
#   validation accuracy (phrase):		12.50 %
# Saving Model ...
